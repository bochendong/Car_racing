# %% [markdown]
# <a href="https://colab.research.google.com/github/bochendong/car_racing/blob/main/dsn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Global Enviorment Settings

# %%
# !git clone https://github.com/bochendong/car_racing.git
# Out:
# fatal: destination path 'car_racing' already exists and is not an empty directory.

# %%
# %%capture
# !sudo apt update && sudo apt install python-opengl
# !sudo apt update && sudo apt install xvfb
# !pip install gym-notebook-wrapper stable-baselines[mpi] box2d box2d-kengz pyvirtualdisplay pyglet
# !pip install wandb
# !pip install gym==0.21.0
# !pip install pyvirtualdisplay -qq
# !pip install folium==0.2.1
# !apt-get install -y xvfb python-opengl ffmpeg -qq
# !pip install box2d

# %%
import numpy as np
import random

from PIL import Image
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
import torch.optim as optim
from torch.distributions import Beta
from torch.utils.data.sampler import BatchSampler, SubsetRandomSampler

from torch.autograd import Function

import gnwrapper
import gym
from gym import logger as gymlogger
gymlogger.set_level(30)

from IPython.display import HTML
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display
import wandb

# %matplotlib inline
import matplotlib.pyplot as plt
import os
import glob

# %%
# %cd car_racing
import car_racing as cr
# Out:
# /content/car_racing

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)

if (os.path.exists("./output_r")) == False:
    os.mkdir("output_r")
    
for epoch in range (3000):
    files = glob.glob("./output_r/*.png")

    for f in files:
        os.remove(f)
# Out:
# cuda

# %% [markdown]
# # Car Racing Env Wrapper

# %%
class Env():
    def __init__(self, color, seed = 0):
        self.env = gnwrapper.Animation(cr.CarRacing(color = color))
        self.env = cr.CarRacing(color = color)
        self.color = color
        self.env.seed(seed)
        self.reward_threshold = 1000

    def reset(self):
        self.counter = 0
        self.av_r = self.reward_memory()

        self.die = False
        img_rgb = self.env.reset()
        img_rgb = img_rgb / 128. - 1
        self.stack = [img_rgb] * 4
        return np.array(self.stack)

    def step(self, action):
        total_reward = 0
        for i in range(8):
            img_rgb, reward, die, _ = self.env.step(action)

            if die: reward += 100

            if self.color == 'g' and np.mean(img_rgb[:, :, 1]) > 185.0:
                  reward -= 0.05

            total_reward += reward

            done = True if self.av_r(reward) <= -0.1 else False
            if done or die:
                break

        img_rgb = img_rgb / 128. - 1
        self.stack.pop(0)
        self.stack.append(img_rgb)
        assert len(self.stack) == 4
        return np.array(self.stack), total_reward, done, die

    def step_eval(self, action):
        img_rgb, reward, done, _ = self.env.step(action)

        img_rgb = img_rgb / 128. - 1
        self.stack.pop(0)
        self.stack.append(img_rgb)
        return np.array(self.stack), reward, done, _

    def render(self, *arg):
        self.env.render(*arg)

    @staticmethod
    def reward_memory():
        count = 0
        length = 100
        history = np.zeros(length)

        def memory(reward):
            nonlocal count
            history[count] = reward
            count = (count + 1) % length
            return np.mean(history)

        return memory

# %%
env_green = gnwrapper.Animation(cr.CarRacing())
env_green = cr.CarRacing(color = 'g')
obs = env_green.reset()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/spaces/box.py:74: UserWarning: WARN: Box bound precision lowered by casting to float32
#   "Box bound precision lowered by casting to {}".format(self.dtype)
# /usr/local/lib/python3.7/dist-packages/gym/spaces/box.py:74: UserWarning: WARN: Box bound precision lowered by casting to float32
#   "Box bound precision lowered by casting to {}".format(self.dtype)

# %%
def get_random(state):
    red_scale, green_scale, blue_scale = 1., 1., 1.
    base_scale = 0.5
    while (red_scale == green_scale == blue_scale):
        add_green = random.randint(0, 1)
        add_red = random.randint(0, 1)
        add_blue = random.randint(0, 1)
        if (add_red): 
            red_scale = random.uniform(0.5, 1.1)
        if (add_green): 
            green_scale = random.uniform(0.5, 1.1)
        if (add_blue): 
            blue_scale = random.uniform(0.5, 1.1)
            
    for i in range (0, 4):
        s = torch.transpose(state[i], 0, 2)
        road = s [1] - s [0] * 0.6 - s[2] * 0.4
        road = torch.stack((road, road, road), 0)
        ones = torch.ones(3, 96, 96).to(device)

        road_mask = torch.logical_xor(road, ones)
        road_layer = s * road_mask

        light_green = 204 / 128. - 1
        light_green_mask = torch.logical_xor(s - light_green , ones)
        light_green_layer = s * light_green_mask

        dark_green = 230 / 128. - 1
        dark_green_mask = torch.logical_xor(s - dark_green , ones)
        dark_green_layer = s * dark_green_mask

        bg_layer = light_green_layer + dark_green_layer

        ones = torch.ones(96, 96).to(device)
        back_ground_mask = torch.logical_xor(bg_layer[1], ones)

        red_channel = (back_ground_mask * 128) /128. - 1
        green_channel = (back_ground_mask * 128) /128. - 1
        blue_channel = (back_ground_mask * 128) /128. - 1

        if (add_red): red_channel = bg_layer[1] * red_scale
        if (add_green): green_channel = bg_layer[1] * green_scale
        if (add_blue): blue_channel = bg_layer[1] * blue_scale

        new_bg_layer = torch.stack((red_channel, green_channel, blue_channel), 0)

        new_state = new_bg_layer + road_layer

        state[i] = torch.transpose(new_state, 0, 2)
        
    return state  

def get_random_buffer(buffer, batch_size):
    target_buffer = buffer.clone()
    for i in range (batch_size):
        target_buffer[i] = get_random(target_buffer[i])
    return target_buffer

# %% [markdown]
# # DSN Model

# %%
class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha
        return output, None  

class DSN(nn.Module):
    def __init__(self):
        super(DSN, self).__init__()
        
        self.sketch = nn.Sequential(
            nn.Conv3d(4, 4, kernel_size=(1, 1, 3), stride=1),
            nn.ReLU(),
        )

        self.source_encoder = nn.Sequential(
            nn.Conv2d(4, 8, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(8, 16, kernel_size=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=2),
            nn.ReLU(),
        )
        
        self.target_encoder = nn.Sequential(
            nn.Conv2d(4, 8, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(8, 16, kernel_size=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=2),
            nn.ReLU(),
        )

        self.shared_encoder = nn.Sequential(
            nn.Conv2d(4, 8, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(8, 16, kernel_size=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(32, 48, kernel_size=3, stride=2),
            nn.ReLU(),
        )

        self.source_fc = nn.Sequential(
            nn.Linear(in_features = 64 * 5 * 5, out_features = 512),
            nn.ReLU(True)
            )
        
        self.target_fc = nn.Sequential(
            nn.Linear(in_features = 64 * 5 * 5, out_features=512),
            nn.ReLU(True)
            )
        
        self.shared_fc = nn.Sequential(
            nn.Linear(in_features= 48 * 5 * 5, out_features=512),
            nn.ReLU(True)
            )
        
        self.pred_domain = nn.Sequential(
            nn.Linear(in_features=512, out_features=128),
            nn.ReLU(True),
            nn.Linear(in_features=128, out_features=2)
        )
        self.shared_decoder_fc = nn.Sequential(nn.Linear(in_features=512, out_features=64 * 5 * 5))

        self.shared_decoder_conv = nn.Sequential(
            nn.ConvTranspose2d(64, 32, 3, stride=2),
            nn.ReLU(True),
            nn.ConvTranspose2d(32, 16, 3, stride=2),
            nn.ReLU(True),
            nn.ConvTranspose2d(16, 8, 3, stride=2),
            nn.ReLU(True),
            nn.ConvTranspose2d(8, 4, 4, stride=2),
            nn.ReLU(True),
        )

        self.shared_decoder_expand = nn.Sequential(
            nn.ConvTranspose3d(4, 4, kernel_size = (1, 1, 3), stride=1),
            nn.Tanh()
        )

        self.v = nn.Sequential(nn.Linear(512, 100), nn.ReLU(), nn.Linear(100, 1))
        self.fc = nn.Sequential(nn.Linear(512, 100), nn.ReLU())
        self.alpha_head = nn.Sequential(nn.Linear(100, 3), nn.Softplus())
        self.beta_head = nn.Sequential(nn.Linear(100, 3), nn.Softplus())
        self.apply(self._weights_init)

    def forward(self, input, get_v = False, input_type = "Source", eta = 0.1):
        sketch = self.sketch(input)
        sketch = torch.squeeze(sketch)
        # Shared
        shared_encode = self.shared_encoder(sketch)
        shared_encode = shared_encode.view(-1, 48 * 5 * 5)
        shared_encode = self.shared_fc(shared_encode)

        if (get_v): return self.v(shared_encode)

        # Private
        if (input_type == "Source" or input_type == "S"):
            private_encode = self.source_encoder(sketch)
            private_encode = private_encode.view(-1, 64 * 5 * 5)
            private_encode = self.source_fc(private_encode)

            v = self.v(shared_encode)
            out = self.fc(shared_encode)
            alpha = self.alpha_head(out) + 1
            beta = self.beta_head(out) + 1
        else:
            private_encode = self.target_encoder(sketch)
            private_encode = private_encode.view(-1, 64 * 5 * 5)
            private_encode = self.target_fc(private_encode)

        # Domain
        reversed_shared_code = ReverseLayerF.apply(shared_encode, eta)
        domain_label = self.pred_domain(reversed_shared_code)

        # Decoder
        rec_vec = self.shared_decoder_fc(private_encode + shared_encode)
        rec_vec = rec_vec.view(-1, 64, 5, 5)
        rec_code = self.shared_decoder_conv(rec_vec)
        rec_code = rec_code.unsqueeze(-1)
        rec_code = self.shared_decoder_expand(rec_code)

        if (input_type == "Source" or input_type == "S"):
            return (alpha, beta), v, domain_label, rec_code, shared_encode, private_encode
        else:
            return domain_label, rec_code, shared_encode, private_encode

    @staticmethod
    def _weights_init(m):
        if isinstance(m, nn.Conv2d):
            nn.init.xavier_uniform_(m.weight, gain=nn.init.calculate_gain('relu'))
            nn.init.constant_(m.bias, 0.1)

# %% [markdown]
# # Loss Functions

# %%
class MSE(nn.Module):
    def __init__(self):
        super(MSE, self).__init__()

    def forward(self, pred, real):
        diffs = torch.add(real, -pred)
        n = torch.numel(diffs.data)
        mse = torch.sum(diffs.pow(2)) / n

        return mse


class SIMSE(nn.Module):

    def __init__(self):
        super(SIMSE, self).__init__()

    def forward(self, pred, real):
        diffs = torch.add(real, - pred)
        n = torch.numel(diffs.data)
        simse = torch.sum(diffs).pow(2) / (n ** 2)

        return simse


class DiffLoss(nn.Module):

    def __init__(self):
        super(DiffLoss, self).__init__()

    def forward(self, input1, input2):

        batch_size = input1.size(0)
        input1 = input1.view(batch_size, -1)
        input2 = input2.view(batch_size, -1)

        input1_l2_norm = torch.norm(input1, p=2, dim=1, keepdim=True).detach()
        input1_l2 = input1.div(input1_l2_norm.expand_as(input1) + 1e-6)

        input2_l2_norm = torch.norm(input2, p=2, dim=1, keepdim=True).detach()
        input2_l2 = input2.div(input2_l2_norm.expand_as(input2) + 1e-6)

        diff_loss = torch.mean((input1_l2.t().mm(input2_l2)).pow(2))

        return diff_loss

# %%
loss_classification = torch.nn.CrossEntropyLoss().cuda()
loss_recon1 = MSE()
loss_recon2 = SIMSE()
loss_diff = DiffLoss()
loss_similarity = torch.nn.CrossEntropyLoss().cuda()

# %% [markdown]
# # Agent

# %%
class Agent():
    max_grad_norm = 0.5
    clip_param = 0.1
    ppo_epoch = 10
    alpha_weight = 0.01
    beta_weight = 0.075
    gamma_weight = 0.5

    transition = np.dtype([('s', np.float64, (4, 96, 96, 3)), ('a', np.float64, (3,)), ('a_logp', np.float64),
                            ('r', np.float64), ('s_', np.float64, (4, 96, 96, 3))])
    
    def __init__(self, net, criterion, optimizer, buffer_capacity = 2048, batch_size = 128):
        self.net = net
        self.buffer_capacity = buffer_capacity
        self.batch_size = batch_size
        self.criterion = criterion
        self.optimizer = optimizer

        self.source_buffer = np.empty(self.buffer_capacity, dtype=self.transition)
        self.counter = 0

    def select_action(self, state):
        state = torch.from_numpy(state).double().to(device).unsqueeze(0)
        with torch.no_grad():
            alpha, beta = self.net(state)[0]

        dist = Beta(alpha, beta)
        action = dist.sample()
        a_logp = dist.log_prob(action).sum(dim=1)

        action = action.squeeze().cpu().numpy()
        a_logp = a_logp.item()
        return action, a_logp

    def store(self, transition):
        self.source_buffer[self.counter] = transition
        self.counter += 1
        if self.counter == self.buffer_capacity:
            self.counter = 0
            return True

        return False

    def update(self, epoch, eta = 0.1):
        s = torch.tensor(self.source_buffer['s'], dtype=torch.double).to(device)
        a = torch.tensor(self.source_buffer['a'], dtype=torch.double).to(device)
        r = torch.tensor(self.source_buffer['r'], dtype=torch.double).to(device).view(-1, 1)
        s_ = torch.tensor(self.source_buffer['s_'], dtype=torch.double).to(device)
        old_a_logp = torch.tensor(self.source_buffer['a_logp'], dtype=torch.double).to(device).view(-1, 1)

        source_domain_label = torch.zeros(self.batch_size).long()
        target_domain_label = torch.ones(self.batch_size).long()
        source_domain_label = source_domain_label.to(device)
        target_domain_label = target_domain_label.to(device)

        with torch.no_grad():
            target_v = r + 0.99 * self.net(s_, get_v = True)
            adv = target_v - self.net(s, get_v = True)

        image_array = []
        source_acc_array, target_acc_array = [], []
        s_loss, t_loss = [0, 0], [0, 0]
        for _ in range(self.ppo_epoch):
            total = 0
            source_domain_correct, target_domain_correct = 0, 0
            add_image = True
            for index in BatchSampler(SubsetRandomSampler(range(self.buffer_capacity)), self.batch_size, True):
                total += self.batch_size
                # Source
                (alpha, beta), v, domain_label, rec_code_s, shared_encode, private_encode = self.net(s[index], eta = eta)
                _, predicted = torch.max(domain_label.data, 1)
                source_domain_correct += predicted.eq(source_domain_label.data).cpu().sum().item()

                # PPO update
                dist = Beta(alpha, beta)
                a_logp = dist.log_prob(a[index]).sum(dim=1, keepdim=True)
                ratio = torch.exp(a_logp - old_a_logp[index])
                surr1 = ratio * adv[index]
                surr2 = torch.clamp(ratio, 1.0 - self.clip_param, 1.0 + self.clip_param) * adv[index]

                # Loss
                similarity_loss = self.gamma_weight * loss_similarity(domain_label, source_domain_label)
                recon_loss_1 = self.alpha_weight * loss_recon1(rec_code_s, s[index])
                recon_loss_2 = self.alpha_weight * loss_recon2(rec_code_s, s[index])
                action_loss = -torch.min(surr1, surr2).mean()
                value_loss = F.smooth_l1_loss(v, target_v[index])

                loss = action_loss + 2. * value_loss + similarity_loss + recon_loss_1 + recon_loss_2
                self.net.zero_grad()
                loss.backward()
                self.optimizer.step()

                s_loss[0] += recon_loss_1.cpu().detach().numpy()
                s_loss[1] += recon_loss_2.cpu().detach().numpy()

                # Target
                with torch.no_grad():
                    target_batch = get_random_buffer(s[index], self.batch_size)

                domain_label, rec_code_t, shared_encode, private_encode = self.net(target_batch, input_type = "Target", eta = eta)
                _, predicted = torch.max(domain_label.data, 1)
                target_domain_correct += predicted.eq(target_domain_label.data).cpu().sum().item()
                # Loss
                similarity_loss = self.gamma_weight * loss_similarity(domain_label, target_domain_label)
                recon_loss_1 = self.alpha_weight * loss_recon1(rec_code_t, s[index])
                recon_loss_2 = self.alpha_weight * loss_recon2(rec_code_t, s[index])


                loss = similarity_loss + recon_loss_1 + recon_loss_2
                self.net.zero_grad()
                loss.backward()
                self.optimizer.step()

                t_loss[0] += recon_loss_1.cpu().detach().numpy()
                t_loss[1] += recon_loss_2.cpu().detach().numpy()

                if (add_image):
                    image = s[index][0][0].reshape(96, 96, 3)
                    image = (image + 1) / 2
                    image = image.cpu().detach().numpy()
                    image_array.append(image)
                
                    image = target_batch[0][0].reshape(96, 96, 3)
                    image = (image + 1) / 2
                    image = image.cpu().detach().numpy()
                    image_array.append(image)

                    image = rec_code_s[0][0].reshape(96, 96, 3)
                    image = (image + 1) / 2
                    image = image.cpu().detach().numpy()
                    image_array.append(image)
                
                    image = rec_code_t[0][0].reshape(96, 96, 3)
                    image = (image + 1) / 2
                    image = image.cpu().detach().numpy()
                    image_array.append(image)
                    
                    add_image = False

            source_acc_array.append( source_domain_correct / total )
            target_acc_array.append( target_domain_correct / total )

        source_acc_mean, target_acc_mean = 0, 0
        for acc in source_acc_array: source_acc_mean += acc
        for acc in target_acc_array: target_acc_mean += acc
            
        f, axs = plt.subplots(10, 4, figsize = (16, 30))
        for j in range (0, 10):
            for i in range (0, 4):
              if (i == 0): axs[j][i].set_title("Source")
              elif (i == 1): axs[j][i].set_title("Target")
              elif (i == 2): axs[j][i].set_title("Source Recon")
              elif (i == 3): axs[j][i].set_title("Target Recon")
        axs = axs.flatten()
        for img, ax in zip(image_array, axs):
            ax.imshow(img)
        f.savefig('./output_r/Recon_image_%04d.png' % epoch)
        plt.close(f)
        
        return source_acc_mean / 10 , target_acc_mean / 10, s_loss, t_loss

# %% [markdown]
# # Agent Trainig

# %%
def eval(agent, env):
    score = 0
    state = env.reset()

    for t in range(1000):
        action, a_logp = agent.select_action(state)

        state_, reward, done, _ = env.step_eval(action * np.array([2., 1., 1.]) + np.array([-1., 0., 0.]))

        score += reward

        state = state_

        if done:
            break

    return score

# %%
def train(source_env, target_env, agent):
    training_records= []
    running_score_records = []
    running_score = 0
    
    c1_running_score, c2_running_score = 0, 0
    c1_training_records, c2_training_records = [], []
    c1_running_score_records, c2_running_score_records = [], []

    s_acc_lst, t_acc_lst = [], []
    s_recon_loss_1_lst, t_recon_loss_1_lst = [], []
    s_recon_loss_2_lst, t_recon_loss_2_lst = [], []

    eta = 0.1
    for i_ep in range(3000):
        score = 0
        state = source_env.reset()

        for t in range(1000):
            action, a_logp = agent.select_action(state)
            state_, reward, done, die = source_env.step(action * np.array([2., 1., 1.])\
                                                              + np.array([-1., 0., 0.]))
            score += reward

            should_update = agent.store((state, action, a_logp, reward, state_))

            if should_update: 
                if (i_ep < 500): eta_max =  1.0
                elif (i_ep < 1500): eta_max = 0.9
                else: eta_max = 0.7
                    
                print("eta: %.2f" % eta)
                s_acc, t_acc, s_loss, t_loss = agent.update(epoch = i_ep, eta = eta) 
                s_acc_lst.append(s_acc)
                t_acc_lst.append(t_acc)
                s_recon_loss_1_lst.append(s_loss[0])
                t_recon_loss_1_lst.append(t_loss[0])
                s_recon_loss_2_lst.append(s_loss[1])
                t_recon_loss_2_lst.append(t_loss[1])

                f, axs = plt.subplots(3, 1, figsize = (18, 8))
                axs[0].plot(range(len(s_acc_lst)), s_acc_lst)
                axs[0].plot(range(len(t_acc_lst)), t_acc_lst)
                axs[0].legend(['Source', 'Target'])
                axs[0].set_title("Domain Acc")

                axs[1].plot(range(len(s_recon_loss_1_lst)), s_recon_loss_1_lst)
                axs[1].plot(range(len(t_recon_loss_1_lst)), t_recon_loss_1_lst)
                axs[1].legend(['Source', 'Target'])
                axs[1].set_title("Recon 1")

                axs[2].plot(range(len(s_recon_loss_2_lst)), s_recon_loss_2_lst)
                axs[2].plot(range(len(t_recon_loss_2_lst)), t_recon_loss_2_lst)
                axs[2].legend(['Source', 'Target'])
                axs[2].set_title("Recon 2")

                f.savefig('./output_r/loss_%04d.png' % i_ep)
                plt.close(f)
                
            state = state_

            if done or die: break
                
        training_records.append(score)
        running_score = running_score * 0.99 + score * 0.01
        running_score_records.append(running_score)
        
        c1_score = eval(agent, target_env[0])
        c2_score = eval(agent, target_env[1])
        c1_training_records.append(c1_score)
        c2_training_records.append(c2_score)
        
        c1_running_score = c1_running_score * 0.99 + c1_score * 0.01
        c2_running_score = c2_running_score * 0.99 + c2_score * 0.01
        c1_running_score_records.append(c1_running_score)
        c2_running_score_records.append(c2_running_score)
        
        if (i_ep % 20 == 0):
            print('Ep {}\tLast score: {:.2f}\tMoving average score: {:.2f}'.format(i_ep, score, running_score))
            print('c1 score: {:.2f}\t c1 Moving average: {:.2f}'.format(c1_score, c1_running_score))
            print('c2 score: {:.2f}\t c2 Moving average: {:.2f}'.format(c2_score, c2_running_score))
            
            if (i_ep != 0):
                f, axs = plt.subplots(1, 2, figsize = (16, 8))
                axs[0].plot(range(len(training_records)), training_records)
                axs[1].plot(range(len(running_score_records)), running_score_records)
                axs[0].plot(range(len(c1_training_records)), c1_training_records)
                axs[1].plot(range(len(c1_running_score_records)), c1_running_score_records)
                axs[0].plot(range(len(c2_training_records)), c2_training_records)
                axs[1].plot(range(len(c2_running_score_records)), c2_running_score_records)

                axs[0].legend(['Source', 'Env c1', 'Env c2'])
                axs[0].set_title("Scores")
                axs[1].legend(['Source', 'Env c1', 'Env c2'])
                axs[1].set_title("Average Score")

                f.savefig('./output_r/scores_%04d.png' % i_ep)
                plt.close(f)

# %%
green_env = Env(color = 'g', seed = 0)
env_c1 = Env(color = 'c1', seed = 0)
env_c2 = Env(color = 'c2', seed = 0)

criterion = nn.CrossEntropyLoss().cuda()
net = DSN().double().cuda()
optimizer = optim.Adam(net.parameters(), lr=1e-3)
agent = Agent(net = net,  criterion = criterion,  optimizer = optimizer, buffer_capacity = 2048, batch_size = 128)

source_env = green_env
target_env = [env_c1, env_c2]
train(green_env, target_env, agent)
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/spaces/box.py:74: UserWarning: WARN: Box bound precision lowered by casting to float32
#   "Box bound precision lowered by casting to {}".format(self.dtype)
# Ep 0	Last score: -17.81	Moving average score: -0.18
# c1 score: -22.82	 c1 Moving average: -0.23
# c2 score: -22.82	 c2 Moving average: -0.23
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 20	Last score: -20.23	Moving average score: -3.10
# c1 score: -32.26	 c1 Moving average: -4.64
# c2 score: -32.26	 c2 Moving average: -4.75
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 40	Last score: -17.88	Moving average score: -5.45
# c1 score: -38.65	 c1 Moving average: -8.46
# c2 score: -38.65	 c2 Moving average: -8.62
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 60	Last score: 19.40	Moving average score: -6.82
# c1 score: 2.36	 c1 Moving average: -11.56
# c2 score: -1.57	 c2 Moving average: -11.60
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 80	Last score: -12.69	Moving average score: -8.36
# c1 score: -33.54	 c1 Moving average: -14.22
# c2 score: -33.54	 c2 Moving average: -14.16
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 100	Last score: 28.14	Moving average score: -7.70
# c1 score: 2.19	 c1 Moving average: -15.16
# c2 score: 2.19	 c2 Moving average: -15.09
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 120	Last score: 8.29	Moving average score: -6.64
# c1 score: 1.08	 c1 Moving average: -16.77
# c2 score: 1.08	 c2 Moving average: -16.81
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 140	Last score: -18.08	Moving average score: -5.32
# c1 score: -32.31	 c1 Moving average: -17.36
# c2 score: -35.38	 c2 Moving average: -17.42
# eta: 0.10
# Ep 160	Last score: -0.06	Moving average score: -4.09
# c1 score: -35.48	 c1 Moving average: -17.99
# c2 score: -35.48	 c2 Moving average: -18.07
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 180	Last score: 1.46	Moving average score: -1.44
# c1 score: -30.92	 c1 Moving average: -17.47
# c2 score: -27.63	 c2 Moving average: -17.56
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 200	Last score: 13.86	Moving average score: 0.05
# c1 score: -27.59	 c1 Moving average: -18.70
# c2 score: -27.59	 c2 Moving average: -18.93
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 220	Last score: 11.41	Moving average score: 1.55
# c1 score: -27.39	 c1 Moving average: -19.74
# c2 score: -27.39	 c2 Moving average: -20.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 240	Last score: 6.06	Moving average score: 2.79
# c1 score: -30.46	 c1 Moving average: -19.48
# c2 score: -27.15	 c2 Moving average: -20.13
# Ep 260	Last score: 15.38	Moving average score: 5.55
# c1 score: -41.18	 c1 Moving average: -18.69
# c2 score: -41.18	 c2 Moving average: -19.55
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 280	Last score: 15.27	Moving average score: 7.74
# c1 score: -31.27	 c1 Moving average: -18.74
# c2 score: -27.84	 c2 Moving average: -19.05
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 300	Last score: 14.75	Moving average score: 9.06
# c1 score: -21.99	 c1 Moving average: -19.57
# c2 score: -18.44	 c2 Moving average: -19.65
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 320	Last score: 17.38	Moving average score: 11.04
# c1 score: 23.03	 c1 Moving average: -19.00
# c2 score: 19.87	 c2 Moving average: -19.69
# Ep 340	Last score: 42.01	Moving average score: 12.39
# c1 score: -30.80	 c1 Moving average: -19.63
# c2 score: -27.34	 c2 Moving average: -19.86
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 360	Last score: 56.07	Moving average score: 14.05
# c1 score: -1.57	 c1 Moving average: -18.40
# c2 score: -17.32	 c2 Moving average: -18.84
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 380	Last score: 16.01	Moving average score: 13.97
# c1 score: -32.04	 c1 Moving average: -16.27
# c2 score: -32.04	 c2 Moving average: -17.43
# eta: 0.10
# Ep 400	Last score: 46.82	Moving average score: 14.32
# c1 score: 25.00	 c1 Moving average: -15.54
# c2 score: 28.38	 c2 Moving average: -16.54
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 420	Last score: 9.61	Moving average score: 15.40
# c1 score: -29.53	 c1 Moving average: -16.38
# c2 score: -32.89	 c2 Moving average: -16.36
# eta: 0.10
# Ep 440	Last score: 18.11	Moving average score: 15.47
# c1 score: -10.71	 c1 Moving average: -14.60
# c2 score: -28.57	 c2 Moving average: -14.92
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 460	Last score: 9.41	Moving average score: 16.08
# c1 score: -6.59	 c1 Moving average: -14.41
# c2 score: -12.09	 c2 Moving average: -15.05
# Ep 480	Last score: -18.02	Moving average score: 16.28
# c1 score: -16.08	 c1 Moving average: -13.53
# c2 score: -26.57	 c2 Moving average: -15.97
# eta: 0.10
# Ep 500	Last score: -17.99	Moving average score: 16.69
# c1 score: -32.43	 c1 Moving average: -14.64
# c2 score: -29.05	 c2 Moving average: -15.84
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 520	Last score: 48.35	Moving average score: 17.21
# c1 score: -27.87	 c1 Moving average: -14.13
# c2 score: -27.87	 c2 Moving average: -15.14
# eta: 0.10
# Ep 540	Last score: 25.16	Moving average score: 17.37
# c1 score: -27.15	 c1 Moving average: -13.15
# c2 score: -23.84	 c2 Moving average: -14.95
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 560	Last score: -18.03	Moving average score: 17.89
# c1 score: 53.02	 c1 Moving average: -12.15
# c2 score: 35.23	 c2 Moving average: -12.93
# eta: 0.10
# Ep 580	Last score: 119.52	Moving average score: 21.65
# c1 score: 100.00	 c1 Moving average: -10.18
# c2 score: 103.64	 c2 Moving average: -10.25
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 600	Last score: 29.66	Moving average score: 22.85
# c1 score: -26.91	 c1 Moving average: -8.39
# c2 score: -26.91	 c2 Moving average: -8.36
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 620	Last score: 56.49	Moving average score: 24.23
# c1 score: 0.81	 c1 Moving average: -0.07
# c2 score: -11.29	 c2 Moving average: -3.21
# Ep 640	Last score: 13.02	Moving average score: 26.10
# c1 score: -24.66	 c1 Moving average: 11.89
# c2 score: -10.96	 c2 Moving average: 1.63
# eta: 0.10
# Ep 660	Last score: 45.44	Moving average score: 27.68
# c1 score: -16.96	 c1 Moving average: 37.27
# c2 score: -6.57	 c2 Moving average: 10.29
# Ep 680	Last score: 50.76	Moving average score: 30.05
# c1 score: -16.38	 c1 Moving average: 52.15
# c2 score: -23.34	 c2 Moving average: 8.12
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 700	Last score: 42.56	Moving average score: 34.43
# c1 score: 376.19	 c1 Moving average: 76.08
# c2 score: 368.86	 c2 Moving average: 35.28
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 720	Last score: 27.18	Moving average score: 34.29
# c1 score: 374.52	 c1 Moving average: 113.89
# c2 score: -23.57	 c2 Moving average: 63.08
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 740	Last score: 86.80	Moving average score: 40.75
# c1 score: 48.70	 c1 Moving average: 134.72
# c2 score: 44.98	 c2 Moving average: 90.06
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 760	Last score: 50.91	Moving average score: 42.87
# c1 score: 28.62	 c1 Moving average: 161.16
# c2 score: 28.62	 c2 Moving average: 124.73
# Ep 780	Last score: 121.32	Moving average score: 44.51
# c1 score: 379.87	 c1 Moving average: 180.24
# c2 score: 363.09	 c2 Moving average: 147.01
# eta: 0.10
# Ep 800	Last score: 122.96	Moving average score: 59.80
# c1 score: 209.04	 c1 Moving average: 193.90
# c2 score: 200.29	 c2 Moving average: 164.87
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 820	Last score: 302.29	Moving average score: 73.65
# c1 score: 365.80	 c1 Moving average: 208.11
# c2 score: 326.71	 c2 Moving average: 181.92
# eta: 0.10
# eta: 0.10
# Ep 840	Last score: 56.09	Moving average score: 93.42
# c1 score: 367.86	 c1 Moving average: 219.72
# c2 score: 360.71	 c2 Moving average: 199.43
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 860	Last score: 216.55	Moving average score: 122.53
# c1 score: 305.32	 c1 Moving average: 229.89
# c2 score: 361.79	 c2 Moving average: 216.32
# eta: 0.10
# Ep 880	Last score: 157.45	Moving average score: 147.62
# c1 score: 347.28	 c1 Moving average: 245.64
# c2 score: 321.73	 c2 Moving average: 229.45
# eta: 0.10
# eta: 0.10
# Ep 900	Last score: 508.50	Moving average score: 181.88
# c1 score: 452.54	 c1 Moving average: 266.75
# c2 score: 428.81	 c2 Moving average: 251.67
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 920	Last score: 790.74	Moving average score: 213.12
# c1 score: 500.00	 c1 Moving average: 279.64
# c2 score: 466.10	 c2 Moving average: 266.47
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 940	Last score: 552.66	Moving average score: 262.64
# c1 score: 522.95	 c1 Moving average: 305.14
# c2 score: 483.61	 c2 Moving average: 294.21
# eta: 0.10
# Ep 960	Last score: 952.30	Moving average score: 324.77
# c1 score: 656.76	 c1 Moving average: 332.95
# c2 score: 587.26	 c2 Moving average: 314.18
# eta: 0.10
# eta: 0.10
# Ep 980	Last score: 766.10	Moving average score: 384.88
# c1 score: 512.50	 c1 Moving average: 373.08
# c2 score: 487.50	 c2 Moving average: 350.41
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 1000	Last score: 818.99	Moving average score: 420.56
# c1 score: 668.38	 c1 Moving average: 385.17
# c2 score: 620.59	 c2 Moving average: 380.80
# eta: 0.10
# eta: 0.10
# Ep 1020	Last score: 762.26	Moving average score: 471.68
# c1 score: 723.10	 c1 Moving average: 423.54
# c2 score: 679.78	 c2 Moving average: 414.09
# eta: 0.10
# eta: 0.10
# Ep 1040	Last score: 811.61	Moving average score: 529.26
# c1 score: 566.67	 c1 Moving average: 465.39
# c2 score: 547.98	 c2 Moving average: 452.02
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 1060	Last score: 854.61	Moving average score: 577.31
# c1 score: 680.58	 c1 Moving average: 499.48
# c2 score: 673.38	 c2 Moving average: 485.21
# eta: 0.10
# eta: 0.10
# Ep 1080	Last score: 932.10	Moving average score: 627.39
# c1 score: 542.64	 c1 Moving average: 523.64
# c2 score: 515.62	 c2 Moving average: 510.36
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 1100	Last score: 971.30	Moving average score: 671.05
# c1 score: 737.74	 c1 Moving average: 553.22
# c2 score: 756.60	 c2 Moving average: 539.97
# eta: 0.10
# eta: 0.10
# Ep 1120	Last score: 830.72	Moving average score: 710.75
# c1 score: 632.70	 c1 Moving average: 577.81
# c2 score: 635.85	 c2 Moving average: 569.27
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 1140	Last score: 866.25	Moving average score: 749.24
# c1 score: 751.06	 c1 Moving average: 603.06
# c2 score: 740.43	 c2 Moving average: 596.89
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 1160	Last score: 983.40	Moving average score: 777.86
# c1 score: 812.41	 c1 Moving average: 627.55
# c2 score: 808.76	 c2 Moving average: 623.56
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 1180	Last score: 969.60	Moving average score: 803.02
# c1 score: 732.24	 c1 Moving average: 650.33
# c2 score: 719.08	 c2 Moving average: 647.83
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 1200	Last score: 865.19	Moving average score: 829.07
# c1 score: 906.60	 c1 Moving average: 670.47
# c2 score: 905.00	 c2 Moving average: 667.09
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 1220	Last score: 973.90	Moving average score: 842.80
# c1 score: 783.96	 c1 Moving average: 686.27
# c2 score: 770.31	 c2 Moving average: 683.05
# eta: 0.10
# eta: 0.10
# Ep 1240	Last score: 998.10	Moving average score: 856.64
# c1 score: 905.00	 c1 Moving average: 703.32
# c2 score: 907.60	 c2 Moving average: 700.34
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 1260	Last score: 977.90	Moving average score: 864.56
# c1 score: 795.97	 c1 Moving average: 713.73
# c2 score: 792.62	 c2 Moving average: 712.54
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 1280	Last score: 862.44	Moving average score: 868.47
# c1 score: 755.74	 c1 Moving average: 724.44
# c2 score: 791.80	 c2 Moving average: 724.55
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 1300	Last score: 829.76	Moving average score: 878.52
# c1 score: 645.45	 c1 Moving average: 732.61
# c2 score: 654.55	 c2 Moving average: 735.38
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 1320	Last score: 869.85	Moving average score: 890.41
# c1 score: 864.16	 c1 Moving average: 747.42
# c2 score: 882.08	 c2 Moving average: 752.06
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 1340	Last score: 981.10	Moving average score: 900.94
# c1 score: 739.12	 c1 Moving average: 759.07
# c2 score: 783.28	 c2 Moving average: 767.37
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 1360	Last score: 993.80	Moving average score: 901.90
# c1 score: 878.10	 c1 Moving average: 769.41
# c2 score: 902.20	 c2 Moving average: 779.48
# eta: 0.10
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 1380	Last score: 970.90	Moving average score: 909.40
# c1 score: 719.28	 c1 Moving average: 780.56
# c2 score: 740.36	 c2 Moving average: 790.88
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 1400	Last score: 541.28	Moving average score: 914.96
# c1 score: 840.20	 c1 Moving average: 793.49
# c2 score: 870.10	 c2 Moving average: 804.25
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 1420	Last score: 988.40	Moving average score: 914.12
# c1 score: 841.75	 c1 Moving average: 802.84
# c2 score: 854.69	 c2 Moving average: 814.30
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 1440	Last score: 855.55	Moving average score: 925.97
# c1 score: 820.63	 c1 Moving average: 813.70
# c2 score: 833.33	 c2 Moving average: 825.94
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# Ep 1460	Last score: 866.65	Moving average score: 920.50
# c1 score: 803.43	 c1 Moving average: 817.66
# c2 score: 819.00	 c2 Moving average: 830.60
# eta: 0.10
# eta: 0.10
# Ep 1480	Last score: 1004.10	Moving average score: 909.71
# c1 score: 911.90	 c1 Moving average: 823.46
# c2 score: 915.40	 c2 Moving average: 836.25
# eta: 0.10
# Ep 1500	Last score: 1015.50	Moving average score: 907.95
# c1 score: 919.20	 c1 Moving average: 832.25
# c2 score: 923.20	 c2 Moving average: 844.57
# eta: 0.10
# Ep 1520	Last score: 874.88	Moving average score: 916.45
# c1 score: 885.35	 c1 Moving average: 841.64
# c2 score: 885.35	 c2 Moving average: 852.74
# eta: 0.10
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 1540	Last score: 1007.70	Moving average score: 923.98
# c1 score: 912.20	 c1 Moving average: 848.87
# c2 score: 914.60	 c2 Moving average: 858.83
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 1560	Last score: 1010.90	Moving average score: 920.20
# c1 score: 884.73	 c1 Moving average: 853.88
# c2 score: 920.10	 c2 Moving average: 860.88
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# eta: 0.10
# Ep 1580	Last score: 1008.90	Moving average score: 923.98
# c1 score: 913.70	 c1 Moving average: 859.21
# c2 score: 917.20	 c2 Moving average: 865.69
# eta: 0.10
# Ep 1600	Last score: 861.07	Moving average score: 904.17
# c1 score: 882.33	 c1 Moving average: 860.21
# c2 score: 882.33	 c2 Moving average: 866.66
# eta: 0.10
