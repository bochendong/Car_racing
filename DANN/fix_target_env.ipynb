# %% [markdown]
# # Colab env settings

# %%
# !git clone https://github.com/bochendong/car_racing.git
# Out:
# fatal: destination path 'car_racing' already exists and is not an empty directory.

# %%
# %%capture
# !sudo apt update && sudo apt install python-opengl
# !sudo apt update && sudo apt install xvfb
# !pip install gym-notebook-wrapper stable-baselines[mpi] box2d box2d-kengz pyvirtualdisplay pyglet
# !pip install wandb
# !pip install gym==0.21.0
# !pip install pyvirtualdisplay -qq
# !pip install folium==0.2.1
# !apt-get install -y xvfb python-opengl ffmpeg -qq

# %%
import numpy as np

from PIL import Image
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
import torch.optim as optim
from torch.distributions import Beta
from torch.utils.data.sampler import BatchSampler, SubsetRandomSampler

from torch.autograd import Function

import gnwrapper
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(30)

from IPython.display import HTML
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display
import wandb

is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

# %%
# !pip install box2d
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: box2d in /usr/local/lib/python3.7/dist-packages (2.3.10)

# %%
# Use cuda if present
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device available for running: ")
print(device)
# Out:
# Device available for running:
# cuda

# %%
# %cd car_racing
# Out:
# /content/car_racing

# %%
import car_racing as cr
import replay_memory as rm

# %%
import os
if (os.path.exists("./output")) == False:
    os.mkdir("output")

# %% [markdown]
# # Carracing Enviorment settings

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %%
env_green = gnwrapper.Animation(cr.CarRacing())
env_green = cr.CarRacing(color = 'g')
obs = env_green.reset()

env_c1 = gnwrapper.Animation(cr.CarRacing(color = 'c1'))
env_c1 = cr.CarRacing(color = 'c1')
obs = env_c1.reset()

env_c2 = gnwrapper.Animation(cr.CarRacing(color = 'c2'))
env_c2 = cr.CarRacing(color = 'c2')
obs = env_c2.reset()

env_b1 = gnwrapper.Animation(cr.CarRacing(color = 'b1'))
env_b1 = cr.CarRacing(color = 'b1')
obs = env_b1.reset()

env_b2 = gnwrapper.Animation(cr.CarRacing(color = 'b2'))
env_b2 = cr.CarRacing(color = 'b2')
obs = env_b2.reset()

env_b3 = gnwrapper.Animation(cr.CarRacing(color = 'b3'))
env_b3 = cr.CarRacing(color = 'b3')
obs = env_b3.reset()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
discrete_actions = {0 : np.array([0,0,0]),       # do nothing
                                 1 : np.array([-1,0,0]),      # steer sharp left
                                 2 : np.array([1,0,0]),       # steer sharp right
                                 3 : np.array([-0.5,0,0]),    # steer left
                                 4 : np.array([0.5,0,0]),     # steer right
                                 5 : np.array([0,1,0]),       # accelerate 100%
                                 6 : np.array([0,0.5,0]),     # accelerate 50%
                                 7 : np.array([0,0.25,0]),    # accelerate 25%
                                 8 : np.array([0,0,1]),       # brake 100%
                                 9 : np.array([0,0,0.5]),     # brake 50%
                                 10 : np.array([0,0,0.25])}   # brake 25%

def get_obs(env):
    n_actions = len(discrete_actions)
    for i in range (0, 40):
        action = torch.randint(low=0, high=11, size=(1,))
        action_transfered = discrete_actions.get(int(action[0]))

        obs, reward, done, _ = env.step([action_transfered[0], action_transfered[1], action_transfered[2]])

    return obs

# %%
f, axs = plt.subplots(2, 3, figsize = (12, 4))

axs = axs.flatten()

env_preview = []

env_preview.append(get_obs(env_green))
env_preview.append(get_obs(env_c1))
env_preview.append(get_obs(env_c2))
env_preview.append(get_obs(env_b1))
env_preview.append(get_obs(env_b2))
env_preview.append(get_obs(env_b3))


for img, ax in zip(env_preview, axs):
    ax.imshow(img)
plt.show()

# %% [markdown]
# # PPO Models

# %%
class Env():
    def __init__(self, color, seed = 0):
        self.env = gnwrapper.Animation(cr.CarRacing(color = color))
        self.env = cr.CarRacing(color = color)
        self.color = color
        self.env.seed(seed)
        self.reward_threshold = 1000

    def reset(self):
        self.counter = 0
        self.av_r = self.reward_memory()

        self.die = False
        img_rgb = self.env.reset()
        img_rgb = img_rgb / 128. - 1
        self.stack = [img_rgb] * 4
        return np.array(self.stack)

    def step(self, action):
        total_reward = 0
        for i in range(8):
            img_rgb, reward, die, _ = self.env.step(action)

            if die: reward += 100

            if self.color == 'g' and np.mean(img_rgb[:, :, 1]) > 185.0:
                  reward -= 0.05

            total_reward += reward

            done = True if self.av_r(reward) <= -0.1 else False
            if done or die:
                break

        img_rgb = img_rgb / 128. - 1
        self.stack.pop(0)
        self.stack.append(img_rgb)
        assert len(self.stack) == 4
        return np.array(self.stack), total_reward, done, die

    def step_eval(self, action):
        img_rgb, reward, done, _ = self.env.step(action)

        img_rgb = img_rgb / 128. - 1
        self.stack.pop(0)
        self.stack.append(img_rgb)
        return np.array(self.stack), reward, done, _

    def render(self, *arg):
        self.env.render(*arg)

    @staticmethod
    def reward_memory():
        count = 0
        length = 100
        history = np.zeros(length)

        def memory(reward):
            nonlocal count
            history[count] = reward
            count = (count + 1) % length
            return np.mean(history)

        return memory

# %%
class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None  

class DANN(nn.Module):
    def __init__(self, num_out):
        super(DANN, self).__init__()
        self.sketch = nn.Sequential(
            nn.Conv3d(4, 4, kernel_size=(1, 1, 3), stride=1),
            nn.ReLU(),
        )
        self.feature = nn.Sequential(  # input shape (4, 96, 96)
            nn.Conv2d(4, 8, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(8, 16, kernel_size=3, stride=2),  # (8, 47, 47)
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=2),  # (16, 23, 23)
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=2),  # (32, 11, 11)
            nn.ReLU(),
        )

        self.cnn_base = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=1),  # (64, 5, 5)
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=3, stride=1),  # (128, 3, 3)
            nn.ReLU(),
        )

        self.domain_classifier = nn.Sequential(
            nn.Linear(64 * 5 * 5, 1000),
            nn.BatchNorm1d(1000),
            nn.ReLU(True),
            nn.Linear(1000, 100),
            nn.BatchNorm1d(100),
            nn.ReLU(True),
            nn.Linear(100, num_out),
        )

        self.v = nn.Sequential(nn.Linear(256, 100), nn.ReLU(), nn.Linear(100, 1))
        self.fc = nn.Sequential(nn.Linear(256, 100), nn.ReLU())
        self.alpha_head = nn.Sequential(nn.Linear(100, 3), nn.Softplus())
        self.beta_head = nn.Sequential(nn.Linear(100, 3), nn.Softplus())
        self.apply(self._weights_init)
      
    def forward(self, input, a = 0.1):
        sketch = self.sketch(input)
        sketch = torch.squeeze(sketch)

        feature = self.feature(sketch)

        out = self.cnn_base(feature)
        out = out.view(-1, 256)
        v = self.v(out)
        out = self.fc(out)

        alpha = self.alpha_head(out) + 1
        beta = self.beta_head(out) + 1

        feature = feature.view(-1, 64 * 5 * 5)
        reverse_feature = ReverseLayerF.apply(feature, a)
        domain_output = self.domain_classifier(reverse_feature)

        return (alpha, beta), v, domain_output

    @staticmethod
    def _weights_init(m):
        if isinstance(m, nn.Conv2d):
            nn.init.xavier_uniform_(m.weight, gain=nn.init.calculate_gain('relu'))
            nn.init.constant_(m.bias, 0.1)

# %% [markdown]
# # Agent

# %%
class Agent():
    max_grad_norm = 0.5
    clip_param = 0.1
    ppo_epoch = 10

    transition = np.dtype([('s', np.float64, (4, 96, 96, 3)), ('a', np.float64, (3,)), ('a_logp', np.float64),
                       ('r', np.float64), ('s_', np.float64, (4, 96, 96, 3))])
    target_transition_2 =  np.dtype([('0', np.float64, (4, 96, 96, 3)), ('1', np.float64, (4, 96, 96, 3))])
    target_transition_3 =  np.dtype([('0', np.float64, (4, 96, 96, 3)), ('1', np.float64, (4, 96, 96, 3)), ('2', np.float64, (4, 96, 96, 3))])

    def __init__(self, num_target, net, criterion, optimizer, buffer_capacity = 2000, batch_size = 128):
        self.net = net
        self.buffer_capacity = buffer_capacity
        self.num_target = num_target
        self.batch_size = batch_size
        self.criterion = criterion
        self.optimizer = optimizer

        self.source_buffer = np.empty(self.buffer_capacity, dtype=self.transition)
        if (num_target == 2):
            self.target_buffer = np.empty(self.buffer_capacity, dtype=self.target_transition_2)
        elif (num_target == 3):
            self.target_buffer = np.empty(self.buffer_capacity, dtype=self.target_transition_3)

        self.counter = 0

    def select_action(self, state):
        state = torch.from_numpy(state).double().to(device).unsqueeze(0)
        with torch.no_grad():
            out = self.net.sketch(state)
            out = torch.squeeze(out)
            out = self.net.feature(out)

            out = self.net.cnn_base(out)
            out = out.view(-1, 256)
            out = self.net.fc(out)
            alpha = self.net.alpha_head(out) + 1
            beta = self.net.beta_head(out) + 1

        dist = Beta(alpha, beta)
        action = dist.sample()
        a_logp = dist.log_prob(action).sum(dim=1)

        action = action.squeeze().cpu().numpy()
        a_logp = a_logp.item()
        return action, a_logp

    def store(self, transition, target_transition):
        self.source_buffer[self.counter] = transition
        self.target_buffer[self.counter] = target_transition
        self.counter += 1
        if self.counter == self.buffer_capacity:
            self.counter = 0
            return True

        return False

    def update(self, epoch, eta = 0.1):
        s = torch.tensor(self.source_buffer['s'], dtype=torch.double).to(device)
        a = torch.tensor(self.source_buffer['a'], dtype=torch.double).to(device)
        r = torch.tensor(self.source_buffer['r'], dtype=torch.double).to(device).view(-1, 1)
        s_ = torch.tensor(self.source_buffer['s_'], dtype=torch.double).to(device)
        old_a_logp = torch.tensor(self.source_buffer['a_logp'], dtype=torch.double).to(device).view(-1, 1)

        domain_labels = {}
        target_data = {}

        for i in range(self.num_target + 1):
            domain_label = torch.full([self.batch_size], i).long()
            domain_label = domain_label.to(device)
            domain_labels[i] = domain_label

        for i in range(self.num_target):
            target_data[i] = torch.tensor(self.target_buffer[str(i)], dtype=torch.double).to(device)

        with torch.no_grad():
            target_v = r + 0.99 * self.net(s_)[1]
            adv = target_v - self.net(s)[1]

        
        for index in BatchSampler(SubsetRandomSampler(range(self.buffer_capacity)), self.batch_size, True):
            image_array = []
            for i in range (self.num_target + 1):
                if (i == 0):
                    image = self.net.sketch(s[index])[0][0]
                    image = image.reshape(96, 96)
                    image = image.cpu().detach().numpy()
                    image_array.append(image)

                else:
                    image = self.net.sketch(target_data[i - 1][index])[0][0]
                    image = image.reshape(96, 96)
                    image = image.cpu().detach().numpy()
                    image_array.append(image)

            f, axs = plt.subplots(1, 4, figsize = (12, 4))
            for img, ax in zip(image_array, axs):
                ax.imshow(img)
            f.savefig('./output/%03d.png' % epoch)
            plt.close(f)
            break
  
        for _ in range(self.ppo_epoch):
            correct = []
            for i in range(self.num_target + 1):
                correct.append(0)
            total = 0
            for index in BatchSampler(SubsetRandomSampler(range(self.buffer_capacity)), self.batch_size, True):
                total += self.batch_size
                loss = 0

                for i in range (self.num_target + 1):
                    if (i == 0):
                        (alpha, beta), v, domain_out = self.net(s[index], eta)
                    else:
                        _, _, domain_out = self.net(target_data[i - 1][index], eta)

                    domain_loss = self.criterion(domain_out, domain_labels[i])
                    loss += domain_loss

                    _, predicted = torch.max(domain_out.data, 1)
                    correct[i] += predicted.eq(domain_labels[i].data).cpu().sum().item()


                dist = Beta(alpha, beta)
                a_logp = dist.log_prob(a[index]).sum(dim=1, keepdim=True)
                ratio = torch.exp(a_logp - old_a_logp[index])
                surr1 = ratio * adv[index]
                surr2 = torch.clamp(ratio, 1.0 - self.clip_param, 1.0 + self.clip_param) * adv[index]
                action_loss = -torch.min(surr1, surr2).mean()
                value_loss = F.smooth_l1_loss(self.net(s[index])[1], target_v[index])

                loss += action_loss + 2. * value_loss
                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

            for i in range(self.num_target + 1):
              print("[Domain %d, Acc: %.2f]" % (i, correct[i]/ total), end = ' ')
            print("")

# %% [markdown]
# # Training

# %%
def eval(agent, env):
    score = 0
    state = env.reset()

    for t in range(1000):
        action, a_logp = agent.select_action(state)

        state_, reward, done, _ = env.step_eval(action * np.array([2., 1., 1.]) + np.array([-1., 0., 0.]))

        score += reward

        state = state_

        if done:
            break

    return score

# %%
def train(source_env, target_envs, unseen_envs, agent):
    num_target = 3
    running_scores = [0]
    for i in range(num_target): running_scores.append(0)
    training_records = {'s' : [[], []], 'b1': [[], []], 'b2' : [[], []], 'b3' : [[], []]}
    
    for i_ep in range(3000):
        scores = [0]
        source_state = source_env.reset()
        target_states = []

        for env in target_envs:
            scores.append(0)
            target_states.append(env.reset())

        if (i_ep < 500): eta = 0.5
        elif (i_ep < 1500): eta = 0.3
        else: eta = 0.1

        for t in range(1000):
            # Source
            source_action, source_a_logp = agent.select_action(source_state)
            source_state_, source_reward, done, die = source_env.step(source_action * np.array([2., 1., 1.]) + np.array([-1., 0., 0.]))
            scores[0] += source_reward

            # Target
            target_actions = []
            for i, state in enumerate(target_states):
                target_action, _ = agent.select_action(state)
                target_actions.append(target_action)

            target_states_ = []
            for i, action in enumerate(target_actions):
                target_state_, target_reward, target_done, target_die = target_envs[i].step(action * np.array([2., 1., 1.]) + np.array([-1., 0., 0.]))
                target_states_.append(target_state_)
                scores[i + 1] += target_reward

                done = done or target_done
                die = die or target_die

            # Update
            should_update = agent.store((source_state, source_action, source_a_logp, source_reward, source_state_), (target_states[0], target_states[1], target_states[2]))

            if should_update: agent.update(epoch = i_ep, eta = eta)

            source_state = source_state_
            target_states = target_states_

            if done or die: break

        for i, score in enumerate(scores):
            running_scores[i] = running_scores[i] * 0.99 + score * 0.01

        if i_ep % 100 == 0:
            for i, score in enumerate(scores):
                print('Domain {}: Ep {}\tLast score: {:.2f}\tMoving average score: {:.2f}'.format(i, i_ep, score, running_scores[i]))
        
        c1_score = eval(agent, unseen_envs[0])
        c2_score = eval(agent, unseen_envs[1])

        print("%.2f" % c1_score)
        print("%.2f" % c2_score)
        
        training_records['s'][0].append(scores[0])
        training_records['s'][1].append(running_scores[0])
        
        training_records['b1'][0].append(scores[1])
        training_records['b1'][1].append(running_scores[1])
        
        training_records['b2'][0].append(scores[2])
        training_records['b2'][1].append(running_scores[2])
        
        training_records['b3'][0].append(scores[3])
        training_records['b3'][1].append(running_scores[3])

        if (c1_score > 850 and c2_score > 850):
            break
    return training_records

# %%
env_green = Env(color = 'g', seed = 0)
env_c1 = Env(color = 'c1', seed = 0)
env_c2 = Env(color = 'c2', seed = 0)
env_b1 = Env(color = 'b1', seed = 0)
env_b2 = Env(color = 'b2', seed = 0)
env_b3 = Env(color = 'b3', seed = 0)


num_target = 3
source_env = env_green
target_envs = [env_b1, env_b2, env_b3]
unseen_envs = [env_c1, env_c2]
running_scores = [0]
for i in range(num_target): running_scores.append(0)

criterion = nn.CrossEntropyLoss().to(device)
net = DANN(num_out = num_target + 1).double().to(device)
optimizer = optim.Adam(net.parameters(), lr=1e-3)

agent = Agent(num_target = num_target, net = net,  criterion = criterion, 
              optimizer = optimizer,
              buffer_capacity = 3000, batch_size = 64)
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
training_records = train(source_env, target_envs, unseen_envs, agent)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# [Domain 0, Acc: 0.80] [Domain 1, Acc: 0.65] [Domain 2, Acc: 0.54] [Domain 3, Acc: 0.72]
# 807.95
# 807.95
# 688.73
# 667.61
# 612.37
# 612.37
# 676.22
# 644.76
# 621.48
# 597.99
# 567.73
# 570.93
# 680.58
# 641.01
# 615.23
# 608.61
# 777.05
# 777.05
# 302.78
# 590.97
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 239.74
# 230.13
# 356.19
# 546.53
# 618.95
# 628.76
# 617.11
# 580.92
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 618.21
# 601.03
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 680.92
# 677.39
# 630.26
# 626.97
# 557.58
# 518.18
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 540.72
# 534.73
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 606.08
# 356.08
# 728.79
# 717.12
# 683.22
# 648.25
# 659.58
# 607.32
# 750.98
# 798.04
# 671.22
# 722.88
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 584.39
# 584.39
# [Domain 0, Acc: 0.22] [Domain 1, Acc: 0.45] [Domain 2, Acc: 0.39] [Domain 3, Acc: 0.60]
# [Domain 0, Acc: 0.38] [Domain 1, Acc: 0.67] [Domain 2, Acc: 0.55] [Domain 3, Acc: 0.64]
# [Domain 0, Acc: 0.47] [Domain 1, Acc: 0.67] [Domain 2, Acc: 0.60] [Domain 3, Acc: 0.65]
# [Domain 0, Acc: 0.52] [Domain 1, Acc: 0.68] [Domain 2, Acc: 0.60] [Domain 3, Acc: 0.69]
# [Domain 0, Acc: 0.53] [Domain 1, Acc: 0.73] [Domain 2, Acc: 0.57] [Domain 3, Acc: 0.71]
# [Domain 0, Acc: 0.62] [Domain 1, Acc: 0.74] [Domain 2, Acc: 0.63] [Domain 3, Acc: 0.70]
# [Domain 0, Acc: 0.62] [Domain 1, Acc: 0.76] [Domain 2, Acc: 0.71] [Domain 3, Acc: 0.74]
# [Domain 0, Acc: 0.70] [Domain 1, Acc: 0.82] [Domain 2, Acc: 0.66] [Domain 3, Acc: 0.73]
# [Domain 0, Acc: 0.68] [Domain 1, Acc: 0.74] [Domain 2, Acc: 0.67] [Domain 3, Acc: 0.71]
# [Domain 0, Acc: 0.70] [Domain 1, Acc: 0.77] [Domain 2, Acc: 0.72] [Domain 3, Acc: 0.73]
# 575.41
# 568.85
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 548.39
# 541.94
# 631.79
# 595.36
# 622.03
# 632.20
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 566.67
# 583.01
# 632.64
# 594.44
# 744.00
# 724.00
# 644.03
# 596.25
# 558.23
# 570.89
# 519.05
# 576.87
# 593.60
# 593.60
# 741.70
# 703.09
# 673.72
# 618.98
# 626.95
# 591.49
# 293.77
# 424.08
# 603.83
# 649.13
# 660.15
# 685.98
# 586.87
# 596.97
# 716.79
# 674.81
# 659.58
# 638.68
# 691.97
# 662.77
# 578.34
# 562.42
# 544.23
# 576.28
# 587.29
# 590.72
# [Domain 0, Acc: 0.53] [Domain 1, Acc: 0.65] [Domain 2, Acc: 0.52] [Domain 3, Acc: 0.35]
# [Domain 0, Acc: 0.50] [Domain 1, Acc: 0.64] [Domain 2, Acc: 0.53] [Domain 3, Acc: 0.40]
# [Domain 0, Acc: 0.62] [Domain 1, Acc: 0.68] [Domain 2, Acc: 0.60] [Domain 3, Acc: 0.46]
# [Domain 0, Acc: 0.55] [Domain 1, Acc: 0.67] [Domain 2, Acc: 0.61] [Domain 3, Acc: 0.48]
# [Domain 0, Acc: 0.63] [Domain 1, Acc: 0.70] [Domain 2, Acc: 0.59] [Domain 3, Acc: 0.47]
# [Domain 0, Acc: 0.63] [Domain 1, Acc: 0.72] [Domain 2, Acc: 0.68] [Domain 3, Acc: 0.53]
# [Domain 0, Acc: 0.73] [Domain 1, Acc: 0.64] [Domain 2, Acc: 0.68] [Domain 3, Acc: 0.54]
# [Domain 0, Acc: 0.68] [Domain 1, Acc: 0.73] [Domain 2, Acc: 0.70] [Domain 3, Acc: 0.58]
# [Domain 0, Acc: 0.65] [Domain 1, Acc: 0.72] [Domain 2, Acc: 0.66] [Domain 3, Acc: 0.54]
# [Domain 0, Acc: 0.67] [Domain 1, Acc: 0.72] [Domain 2, Acc: 0.68] [Domain 3, Acc: 0.58]
# 687.00
# 668.95
# 260.25
# 347.20
# 228.27
# 471.43
# 283.69
# 392.45
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 592.83
# 637.20
# 647.40
# 643.94
# 592.05
# 592.05
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 710.61
# 714.39
# 522.07
# 632.44
# 597.75
# 607.40
# 647.40
# 650.87
# 726.42
# 715.09
# 747.83
# 711.59
# 678.95
# 710.53
# 575.68
# 599.32
# 559.44
# 550.15
# 594.35
# 601.00
# 618.75
# 604.86
# 681.02
# 684.67
# 620.39
# 548.03
# 751.41
# 775.50
# 603.33
# 580.00
# 618.95
# 328.10
# [Domain 0, Acc: 0.33] [Domain 1, Acc: 0.38] [Domain 2, Acc: 0.68] [Domain 3, Acc: 0.38]
# [Domain 0, Acc: 0.42] [Domain 1, Acc: 0.46] [Domain 2, Acc: 0.75] [Domain 3, Acc: 0.42]
# [Domain 0, Acc: 0.46] [Domain 1, Acc: 0.49] [Domain 2, Acc: 0.80] [Domain 3, Acc: 0.46]
# [Domain 0, Acc: 0.50] [Domain 1, Acc: 0.50] [Domain 2, Acc: 0.79] [Domain 3, Acc: 0.52]
# [Domain 0, Acc: 0.53] [Domain 1, Acc: 0.56] [Domain 2, Acc: 0.82] [Domain 3, Acc: 0.55]
# [Domain 0, Acc: 0.54] [Domain 1, Acc: 0.60] [Domain 2, Acc: 0.81] [Domain 3, Acc: 0.53]
# [Domain 0, Acc: 0.58] [Domain 1, Acc: 0.60] [Domain 2, Acc: 0.81] [Domain 3, Acc: 0.59]
# [Domain 0, Acc: 0.59] [Domain 1, Acc: 0.64] [Domain 2, Acc: 0.80] [Domain 3, Acc: 0.61]
# [Domain 0, Acc: 0.58] [Domain 1, Acc: 0.65] [Domain 2, Acc: 0.86] [Domain 3, Acc: 0.60]
# [Domain 0, Acc: 0.63] [Domain 1, Acc: 0.67] [Domain 2, Acc: 0.89] [Domain 3, Acc: 0.60]
# 585.25
# 640.98
# 617.17
# 654.21
# 582.39
# 594.97
# 711.32
# 692.45
# 784.62
# 773.08
# 660.30
# 716.48
# 625.86
# 622.74
# 728.90
# 709.89
# 778.33
# 759.32
# 159.15
# 549.39
# 468.11
# 694.02
# Domain 0: Ep 1800	Last score: 434.36	Moving average score: 383.16
# Domain 1: Ep 1800	Last score: 531.67	Moving average score: 381.70
# Domain 2: Ep 1800	Last score: 444.92	Moving average score: 377.21
# Domain 3: Ep 1800	Last score: 565.23	Moving average score: 384.88
# 665.10
# 628.19
# 680.41
# 666.89
# 579.13
# 560.44
# 751.56
# 552.34
# 791.05
# 771.60
# 619.75
# 600.64
# 604.97
# 583.23
# 730.26
# 667.53
# 785.38
# 726.09
# 653.38
# 673.65
# 603.47
# 578.23
# 620.93
# 634.22
# 531.25
# 593.75
# 741.33
# 719.19
# [Domain 0, Acc: 0.24] [Domain 1, Acc: 0.37] [Domain 2, Acc: 0.35] [Domain 3, Acc: 0.36]
# [Domain 0, Acc: 0.44] [Domain 1, Acc: 0.38] [Domain 2, Acc: 0.38] [Domain 3, Acc: 0.59]
# [Domain 0, Acc: 0.50] [Domain 1, Acc: 0.41] [Domain 2, Acc: 0.43] [Domain 3, Acc: 0.61]
# [Domain 0, Acc: 0.52] [Domain 1, Acc: 0.46] [Domain 2, Acc: 0.52] [Domain 3, Acc: 0.54]
# [Domain 0, Acc: 0.52] [Domain 1, Acc: 0.57] [Domain 2, Acc: 0.49] [Domain 3, Acc: 0.62]
# [Domain 0, Acc: 0.51] [Domain 1, Acc: 0.58] [Domain 2, Acc: 0.56] [Domain 3, Acc: 0.66]
# [Domain 0, Acc: 0.57] [Domain 1, Acc: 0.59] [Domain 2, Acc: 0.52] [Domain 3, Acc: 0.71]
# [Domain 0, Acc: 0.59] [Domain 1, Acc: 0.61] [Domain 2, Acc: 0.58] [Domain 3, Acc: 0.67]
# [Domain 0, Acc: 0.61] [Domain 1, Acc: 0.67] [Domain 2, Acc: 0.62] [Domain 3, Acc: 0.68]
# [Domain 0, Acc: 0.61] [Domain 1, Acc: 0.57] [Domain 2, Acc: 0.56] [Domain 3, Acc: 0.67]
# 709.52
# 672.11
# 617.11
# 610.53
# 852.76
# 805.51
# 681.88
# 712.08
# 296.10
# 607.79
# 839.39
# 824.24
# 740.99
# 772.79
# 700.66
# 677.41
# 539.29
# 742.86
# 709.69
# 733.91
# 743.64
# 772.73
# 638.85
# 635.67
# 807.75
# 778.23
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 801.10
# 797.44
# 727.12
# 730.51
# 779.12
# 801.10
# 689.83
# 696.61
# 765.25
# 772.34
# 428.96
# 842.08
# 660.38
# 676.36
# 691.53
# 691.53
# 844.22
# 820.32
# 813.53
# 832.33
# 825.09
# 813.86
# [Domain 0, Acc: 0.34] [Domain 1, Acc: 0.35] [Domain 2, Acc: 0.40] [Domain 3, Acc: 0.54]
# [Domain 0, Acc: 0.42] [Domain 1, Acc: 0.43] [Domain 2, Acc: 0.46] [Domain 3, Acc: 0.69]
# [Domain 0, Acc: 0.44] [Domain 1, Acc: 0.48] [Domain 2, Acc: 0.44] [Domain 3, Acc: 0.70]
# [Domain 0, Acc: 0.48] [Domain 1, Acc: 0.54] [Domain 2, Acc: 0.47] [Domain 3, Acc: 0.78]
# [Domain 0, Acc: 0.52] [Domain 1, Acc: 0.60] [Domain 2, Acc: 0.47] [Domain 3, Acc: 0.81]
# [Domain 0, Acc: 0.58] [Domain 1, Acc: 0.63] [Domain 2, Acc: 0.56] [Domain 3, Acc: 0.74]
# [Domain 0, Acc: 0.53] [Domain 1, Acc: 0.67] [Domain 2, Acc: 0.48] [Domain 3, Acc: 0.78]
# [Domain 0, Acc: 0.61] [Domain 1, Acc: 0.64] [Domain 2, Acc: 0.54] [Domain 3, Acc: 0.81]
# [Domain 0, Acc: 0.57] [Domain 1, Acc: 0.71] [Domain 2, Acc: 0.52] [Domain 3, Acc: 0.78]
# [Domain 0, Acc: 0.61] [Domain 1, Acc: 0.69] [Domain 2, Acc: 0.58] [Domain 3, Acc: 0.72]
# 763.97
# 782.35
# 784.89
# 745.32
# 827.76
# 861.98
# 687.38
# 710.63
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 769.09
# 743.64
# 842.75
# 816.03
# 628.86
# 602.62
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 720.69
# 717.24
# 734.53
# 752.52
# 687.30
# 630.16
# 738.60
# 731.58
# 721.55
# 701.35
# 665.27
# 671.70
# 572.73
# 600.00
# 774.52
# 759.32
# 833.58
# 796.68
# 721.19
# 704.64
# 818.22
# 799.63
# 737.29
# 716.95
# [Domain 0, Acc: 0.45] [Domain 1, Acc: 0.61] [Domain 2, Acc: 0.46] [Domain 3, Acc: 0.49]
# [Domain 0, Acc: 0.53] [Domain 1, Acc: 0.70] [Domain 2, Acc: 0.48] [Domain 3, Acc: 0.68]
# [Domain 0, Acc: 0.54] [Domain 1, Acc: 0.72] [Domain 2, Acc: 0.53] [Domain 3, Acc: 0.72]
# [Domain 0, Acc: 0.63] [Domain 1, Acc: 0.75] [Domain 2, Acc: 0.67] [Domain 3, Acc: 0.73]
# [Domain 0, Acc: 0.62] [Domain 1, Acc: 0.76] [Domain 2, Acc: 0.60] [Domain 3, Acc: 0.74]
# [Domain 0, Acc: 0.68] [Domain 1, Acc: 0.76] [Domain 2, Acc: 0.65] [Domain 3, Acc: 0.78]
# [Domain 0, Acc: 0.65] [Domain 1, Acc: 0.74] [Domain 2, Acc: 0.69] [Domain 3, Acc: 0.81]
# [Domain 0, Acc: 0.67] [Domain 1, Acc: 0.74] [Domain 2, Acc: 0.66] [Domain 3, Acc: 0.81]
# [Domain 0, Acc: 0.71] [Domain 1, Acc: 0.77] [Domain 2, Acc: 0.73] [Domain 3, Acc: 0.80]
# [Domain 0, Acc: 0.69] [Domain 1, Acc: 0.77] [Domain 2, Acc: 0.74] [Domain 3, Acc: 0.81]
# 682.76
# 755.17
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# retry to generate track (normal if there are not manyinstances of this message)
# 666.36
# 657.01
# 720.60
# 690.70
# 654.05
# 443.69
# 746.15
# 726.09
# 793.24
# 771.89
# 715.07
# 715.07
# 719.35
# 712.90
# 786.45
# 757.14
# 854.89
# 817.29
# 798.92
# 780.87
# 749.65
# 728.67
# 742.70
# 783.90
# 804.06
# 796.68
# 802.88
# 792.09
# 849.37
# 870.46
# 690.38
# 721.31
# 600.30
# 594.36
# 760.93
# 717.88
# 871.07
# 866.94

# %% [markdown]
# # Eval

# %%
def eval(agent, env):
    score = 0
    state = env.reset()

    for t in range(1000):
        action, a_logp = agent.select_action(state)

        state_, reward, done, _ = env.step_eval(action * np.array([2., 1., 1.]) + np.array([-1., 0., 0.]))

        score += reward

        state = state_

        if done:
            break

    return score

# %%
green_score = eval(agent, env_green)
c1_score = eval(agent, env_c1)
c2_score = eval(agent, env_c2)

# %%
print(green_score)
print(c1_score)
print(c2_score)
# Out:
# 792.9889298892883
# 811.4391143911334
# 826.1992619926095
