# %%
import numpy as np

import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Beta
from torch.utils.data.sampler import BatchSampler, SubsetRandomSampler

# %%
class Env():
    def __init__(self):
        self.env = gym.make('CarRacing-v1')
        self.env.seed(0)
        self.reward_threshold = self.env.spec.reward_threshold

    def reset(self):
        self.counter = 0
        self.av_r = self.reward_memory()

        self.die = False
        img_rgb = self.env.reset()
        img_gray = self.rgb2gray(img_rgb)
        self.stack = [img_gray] * 4  # four frames for decision
        return np.array(self.stack)

    def step(self, action):
        total_reward = 0
        for i in range(8):
            img_rgb, reward, die, _ = self.env.step(action)
            # don't penalize "die state"
            if die:
                reward += 100
            # green penalty
            if np.mean(img_rgb[:, :, 1]) > 185.0:
                reward -= 0.05
            total_reward += reward
            # if no reward recently, end the episode
            done = True if self.av_r(reward) <= -0.1 else False
            if done or die:
                break
        img_gray = self.rgb2gray(img_rgb)
        self.stack.pop(0)
        self.stack.append(img_gray)
        assert len(self.stack) == 4
        return np.array(self.stack), total_reward, done, die

    def render(self, *arg):
        self.env.render(*arg)

    @staticmethod
    def rgb2gray(rgb, norm=True):
        # rgb image -> gray [0, 1]
        gray = np.dot(rgb[..., :], [0.299, 0.587, 0.114])
        if norm:
            # normalize
            gray = gray / 128. - 1.
        return gray

    @staticmethod
    def reward_memory():
        # record reward for last 100 steps
        count = 0
        length = 100
        history = np.zeros(length)

        def memory(reward):
            nonlocal count
            history[count] = reward
            count = (count + 1) % length
            return np.mean(history)

        return memory

# %%
class Net(nn.Module):
    """
    Actor-Critic Network for PPO
    """

    def __init__(self):
        super(Net, self).__init__()
        self.cnn_base = nn.Sequential(  # input shape (4, 96, 96)
            nn.Conv2d(4, 8, kernel_size=4, stride=2),
            nn.ReLU(),  # activation
            nn.Conv2d(8, 16, kernel_size=3, stride=2),  # (8, 47, 47)
            nn.ReLU(),  # activation
            nn.Conv2d(16, 32, kernel_size=3, stride=2),  # (16, 23, 23)
            nn.ReLU(),  # activation
            nn.Conv2d(32, 64, kernel_size=3, stride=2),  # (32, 11, 11)
            nn.ReLU(),  # activation
            nn.Conv2d(64, 128, kernel_size=3, stride=1),  # (64, 5, 5)
            nn.ReLU(),  # activation
            nn.Conv2d(128, 256, kernel_size=3, stride=1),  # (128, 3, 3)
            nn.ReLU(),  # activation
        )  # output shape (256, 1, 1)
        self.v = nn.Sequential(nn.Linear(256, 100), nn.ReLU(), nn.Linear(100, 1))
        self.fc = nn.Sequential(nn.Linear(256, 100), nn.ReLU())
        self.alpha_head = nn.Sequential(nn.Linear(100, 3), nn.Softplus())
        self.beta_head = nn.Sequential(nn.Linear(100, 3), nn.Softplus())
        self.apply(self._weights_init)

    @staticmethod
    def _weights_init(m):
        if isinstance(m, nn.Conv2d):
            nn.init.xavier_uniform_(m.weight, gain=nn.init.calculate_gain('relu'))
            nn.init.constant_(m.bias, 0.1)

    def forward(self, x):
        x = self.cnn_base(x)
        x = x.view(-1, 256)
        v = self.v(x)
        x = self.fc(x)
        alpha = self.alpha_head(x) + 1
        beta = self.beta_head(x) + 1

        return (alpha, beta), v

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %%
transition = np.dtype([('s', np.float64, (4, 96, 96)), ('a', np.float64, (3,)), ('a_logp', np.float64),
                       ('r', np.float64), ('s_', np.float64, (4, 96, 96))])

# %%
class Agent():
    """
    Agent for training
    """
    max_grad_norm = 0.5
    clip_param = 0.1  # epsilon in clipped loss
    ppo_epoch = 10
    buffer_capacity, batch_size = 2000, 128

    def __init__(self):
        self.training_step = 0
        self.net = Net().double().to(device)
        self.buffer = np.empty(self.buffer_capacity, dtype=transition)
        self.counter = 0

        self.optimizer = optim.Adam(self.net.parameters(), lr=1e-3)

    def select_action(self, state):
        state = torch.from_numpy(state).double().to(device).unsqueeze(0)
        with torch.no_grad():
            alpha, beta = self.net(state)[0]
        dist = Beta(alpha, beta)
        action = dist.sample()
        a_logp = dist.log_prob(action).sum(dim=1)

        action = action.squeeze().cpu().numpy()
        a_logp = a_logp.item()
        return action, a_logp

    def save_param(self):
        torch.save(self.net.state_dict(), 'param/ppo_net_params.pkl')

    def store(self, transition):
        self.buffer[self.counter] = transition
        self.counter += 1
        if self.counter == self.buffer_capacity:
            self.counter = 0
            return True
        else:
            return False

    def update(self):
        self.training_step += 1

        s = torch.tensor(self.buffer['s'], dtype=torch.double).to(device)
        a = torch.tensor(self.buffer['a'], dtype=torch.double).to(device)
        r = torch.tensor(self.buffer['r'], dtype=torch.double).to(device).view(-1, 1)
        s_ = torch.tensor(self.buffer['s_'], dtype=torch.double).to(device)

        old_a_logp = torch.tensor(self.buffer['a_logp'], dtype=torch.double).to(device).view(-1, 1)

        with torch.no_grad():
            target_v = r + 0.99 * self.net(s_)[1]
            adv = target_v - self.net(s)[1]
            # adv = (adv - adv.mean()) / (adv.std() + 1e-8)

        for _ in range(self.ppo_epoch):
            for index in BatchSampler(SubsetRandomSampler(range(self.buffer_capacity)), self.batch_size, False):

                alpha, beta = self.net(s[index])[0]
                dist = Beta(alpha, beta)
                a_logp = dist.log_prob(a[index]).sum(dim=1, keepdim=True)
                ratio = torch.exp(a_logp - old_a_logp[index])

                surr1 = ratio * adv[index]
                surr2 = torch.clamp(ratio, 1.0 - self.clip_param, 1.0 + self.clip_param) * adv[index]
                action_loss = -torch.min(surr1, surr2).mean()
                value_loss = F.smooth_l1_loss(self.net(s[index])[1], target_v[index])
                loss = action_loss + 2. * value_loss

                self.optimizer.zero_grad()
                loss.backward()
                # nn.utils.clip_grad_norm_(self.net.parameters(), self.max_grad_norm)
                self.optimizer.step()

# %%
render = False

# %%
if __name__ == "__main__":
    agent = Agent()
    env = Env()

    training_records = []
    running_score = 0
    state = env.reset()
    for i_ep in range(100000):
        score = 0
        state = env.reset()

        for t in range(1000):
            action, a_logp = agent.select_action(state)
            state_, reward, done, die = env.step(action * np.array([2., 1., 1.]) + np.array([-1., 0., 0.]))
            if render:
                env.render()
            if agent.store((state, action, a_logp, reward, state_)):
                print('updating')
                agent.update()
            score += reward
            state = state_
            if done or die:
                break
        running_score = running_score * 0.99 + score * 0.01

        if i_ep % 10 == 0:
            print('Ep {}\tLast score: {:.2f}\tMoving average score: {:.2f}'.format(i_ep, score, running_score))
        if running_score > env.reward_threshold:
            print("Solved! Running reward is now {} and the last episode runs to {}!".format(running_score, score))
            break
# Out:
# Track generation: 1265..1585 -> 320-tiles track
# Track generation: 1115..1397 -> 282-tiles track
# Ep 0	Last score: -17.95	Moving average score: -0.18
# Track generation: 1280..1604 -> 324-tiles track
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1176..1484 -> 308-tiles track
# Track generation: 1039..1303 -> 264-tiles track
# Track generation: 1102..1388 -> 286-tiles track
# Track generation: 1240..1554 -> 314-tiles track
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1104..1384 -> 280-tiles track
# Track generation: 1162..1463 -> 301-tiles track
# Track generation: 1267..1588 -> 321-tiles track
# Ep 10	Last score: -17.92	Moving average score: 1.10
# Track generation: 1117..1408 -> 291-tiles track
# Track generation: 1172..1469 -> 297-tiles track
# Track generation: 1207..1513 -> 306-tiles track
# Track generation: 1047..1313 -> 266-tiles track
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1075..1348 -> 273-tiles track
# Track generation: 1121..1411 -> 290-tiles track
# updating
# Track generation: 1099..1383 -> 284-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1224..1534 -> 310-tiles track
# Track generation: 1096..1374 -> 278-tiles track
# Ep 20	Last score: 86.64	Moving average score: 3.32
# Track generation: 1044..1309 -> 265-tiles track
# Track generation: 995..1253 -> 258-tiles track
# Track generation: 1060..1329 -> 269-tiles track
# Track generation: 1149..1444 -> 295-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1126..1412 -> 286-tiles track
# Track generation: 1169..1465 -> 296-tiles track
# Track generation: 926..1163 -> 237-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1064..1335 -> 271-tiles track
# Track generation: 1236..1549 -> 313-tiles track
# Track generation: 967..1213 -> 246-tiles track
# Track generation: 1077..1360 -> 283-tiles track
# Track generation: 1287..1613 -> 326-tiles track
# Ep 30	Last score: -17.95	Moving average score: 3.87
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1279..1602 -> 323-tiles track
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# updating
# Track generation: 1056..1332 -> 276-tiles track
# Track generation: 1320..1654 -> 334-tiles track
# Track generation: 1309..1640 -> 331-tiles track
# Track generation: 1212..1519 -> 307-tiles track
# Track generation: 1023..1283 -> 260-tiles track
# Track generation: 1071..1349 -> 278-tiles track
# Ep 40	Last score: 108.30	Moving average score: 4.04
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1124..1409 -> 285-tiles track
# Track generation: 1195..1498 -> 303-tiles track
# Track generation: 1080..1357 -> 277-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 981..1237 -> 256-tiles track
# Track generation: 1113..1395 -> 282-tiles track
# Track generation: 1141..1430 -> 289-tiles track
# Track generation: 1245..1560 -> 315-tiles track
# Track generation: 1193..1495 -> 302-tiles track
# Track generation: 1240..1554 -> 314-tiles track
# Track generation: 1288..1614 -> 326-tiles track
# Ep 50	Last score: -18.06	Moving average score: 3.02
# Track generation: 1057..1327 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1090..1368 -> 278-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 969..1224 -> 255-tiles track
# updating
# Track generation: 1035..1298 -> 263-tiles track
# Track generation: 1347..1688 -> 341-tiles track
# Track generation: 1165..1461 -> 296-tiles track
# Track generation: 1176..1474 -> 298-tiles track
# Track generation: 1043..1314 -> 271-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1351..1693 -> 342-tiles track
# Track generation: 1012..1269 -> 257-tiles track
# Ep 60	Last score: 85.94	Moving average score: 5.39
# Track generation: 1252..1569 -> 317-tiles track
# Track generation: 1100..1379 -> 279-tiles track
# Track generation: 1040..1304 -> 264-tiles track
# Track generation: 1392..1744 -> 352-tiles track
# Track generation: 1356..1699 -> 343-tiles track
# Track generation: 1246..1562 -> 316-tiles track
# Track generation: 1168..1464 -> 296-tiles track
# Track generation: 1028..1297 -> 269-tiles track
# Track generation: 1049..1315 -> 266-tiles track
# Track generation: 1103..1383 -> 280-tiles track
# updating
# Ep 70	Last score: -17.83	Moving average score: 4.18
# Track generation: 1052..1319 -> 267-tiles track
# Track generation: 1063..1333 -> 270-tiles track
# Track generation: 1328..1671 -> 343-tiles track
# Track generation: 1124..1409 -> 285-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# Track generation: 909..1141 -> 232-tiles track
# Ep 80	Last score: 9.91	Moving average score: 5.26
# Track generation: 1058..1334 -> 276-tiles track
# Track generation: 953..1201 -> 248-tiles track
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1114..1398 -> 284-tiles track
# Track generation: 1151..1443 -> 292-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1070..1347 -> 277-tiles track
# updating
# Track generation: 1071..1343 -> 272-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# Track generation: 1103..1383 -> 280-tiles track
# Ep 90	Last score: 8.44	Moving average score: 7.25
# Track generation: 1151..1443 -> 292-tiles track
# Track generation: 1234..1554 -> 320-tiles track
# Track generation: 1100..1379 -> 279-tiles track
# Track generation: 1300..1629 -> 329-tiles track
# Track generation: 1158..1452 -> 294-tiles track
# Track generation: 1166..1461 -> 295-tiles track
# Track generation: 1039..1304 -> 265-tiles track
# Track generation: 1243..1558 -> 315-tiles track
# Track generation: 1159..1460 -> 301-tiles track
# Track generation: 1170..1467 -> 297-tiles track
# Ep 100	Last score: -18.00	Moving average score: 5.40
# Track generation: 1147..1438 -> 291-tiles track
# Track generation: 1083..1364 -> 281-tiles track
# Track generation: 1028..1289 -> 261-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1097..1375 -> 278-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# updating
# Track generation: 1028..1298 -> 270-tiles track
# Track generation: 1212..1519 -> 307-tiles track
# Track generation: 1032..1303 -> 271-tiles track
# Track generation: 1122..1416 -> 294-tiles track
# Ep 110	Last score: 85.32	Moving average score: 7.84
# Track generation: 1249..1565 -> 316-tiles track
# Track generation: 1229..1540 -> 311-tiles track
# Track generation: 1082..1356 -> 274-tiles track
# Track generation: 1275..1604 -> 329-tiles track
# Track generation: 1304..1634 -> 330-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1245..1569 -> 324-tiles track
# Track generation: 1202..1507 -> 305-tiles track
# Track generation: 1240..1554 -> 314-tiles track
# Track generation: 1296..1624 -> 328-tiles track
# Ep 120	Last score: -17.88	Moving average score: 6.64
# Track generation: 1061..1331 -> 270-tiles track
# Track generation: 1057..1331 -> 274-tiles track
# Track generation: 1047..1313 -> 266-tiles track
# Track generation: 1200..1504 -> 304-tiles track
# updating
# Track generation: 1142..1432 -> 290-tiles track
# Track generation: 1151..1443 -> 292-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1035..1298 -> 263-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1274..1604 -> 330-tiles track
# Ep 130	Last score: -18.03	Moving average score: 7.76
# Track generation: 996..1249 -> 253-tiles track
# Track generation: 1221..1534 -> 313-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1187..1488 -> 301-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# Track generation: 1055..1323 -> 268-tiles track
# Track generation: 1207..1522 -> 315-tiles track
# Track generation: 1292..1619 -> 327-tiles track
# Track generation: 1071..1343 -> 272-tiles track
# Track generation: 1071..1343 -> 272-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# Ep 140	Last score: 91.24	Moving average score: 8.30
# Track generation: 1285..1613 -> 328-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1248..1572 -> 324-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# updating
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1079..1353 -> 274-tiles track
# Track generation: 1027..1288 -> 261-tiles track
# Track generation: 1002..1257 -> 255-tiles track
# Track generation: 1082..1357 -> 275-tiles track
# Track generation: 1111..1393 -> 282-tiles track
# Track generation: 1220..1526 -> 306-tiles track
# Track generation: 1236..1549 -> 313-tiles track
# Ep 150	Last score: -17.99	Moving average score: 8.12
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1055..1323 -> 268-tiles track
# Track generation: 1002..1258 -> 256-tiles track
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1260..1579 -> 319-tiles track
# Track generation: 1145..1440 -> 295-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1192..1494 -> 302-tiles track
# Track generation: 1062..1341 -> 279-tiles track
# updating
# Ep 160	Last score: 17.61	Moving average score: 8.82
# Track generation: 1011..1270 -> 259-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1085..1360 -> 275-tiles track
# Track generation: 1225..1542 -> 317-tiles track
# Track generation: 1015..1273 -> 258-tiles track
# Track generation: 1043..1308 -> 265-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1204..1509 -> 305-tiles track
# Track generation: 1336..1674 -> 338-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1212..1519 -> 307-tiles track
# Ep 170	Last score: 12.83	Moving average score: 8.55
# Track generation: 1080..1354 -> 274-tiles track
# Track generation: 1078..1355 -> 277-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1048..1322 -> 274-tiles track
# Track generation: 1065..1338 -> 273-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1139..1428 -> 289-tiles track
# Track generation: 1288..1614 -> 326-tiles track
# Track generation: 1139..1431 -> 292-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1171..1468 -> 297-tiles track
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1016..1274 -> 258-tiles track
# Track generation: 1130..1415 -> 285-tiles track
# Track generation: 1105..1385 -> 280-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# Ep 180	Last score: 10.83	Moving average score: 7.96
# Track generation: 1166..1462 -> 296-tiles track
# updating
# Track generation: 1319..1654 -> 335-tiles track
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1085..1367 -> 282-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1108..1389 -> 281-tiles track
# Track generation: 1150..1442 -> 292-tiles track
# Track generation: 1052..1319 -> 267-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1025..1289 -> 264-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1220..1529 -> 309-tiles track
# Ep 190	Last score: -17.92	Moving average score: 6.49
# Track generation: 1236..1549 -> 313-tiles track
# Track generation: 1185..1487 -> 302-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1268..1589 -> 321-tiles track
# Track generation: 1113..1395 -> 282-tiles track
# Track generation: 1223..1533 -> 310-tiles track
# Track generation: 1105..1388 -> 283-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1088..1364 -> 276-tiles track
# Track generation: 1048..1314 -> 266-tiles track
# Track generation: 1103..1391 -> 288-tiles track
# Track generation: 1286..1611 -> 325-tiles track
# Track generation: 1067..1338 -> 271-tiles track
# Track generation: 1094..1379 -> 285-tiles track
# Ep 200	Last score: 13.08	Moving average score: 7.07
# Track generation: 1070..1346 -> 276-tiles track
# updating
# Track generation: 1083..1358 -> 275-tiles track
# Track generation: 1236..1549 -> 313-tiles track
# Track generation: 1278..1602 -> 324-tiles track
# Track generation: 1292..1619 -> 327-tiles track
# Track generation: 1111..1393 -> 282-tiles track
# Track generation: 1212..1519 -> 307-tiles track
# Track generation: 1043..1315 -> 272-tiles track
# Track generation: 1291..1618 -> 327-tiles track
# Track generation: 1168..1464 -> 296-tiles track
# Ep 210	Last score: 8.70	Moving average score: 8.68
# Track generation: 1352..1694 -> 342-tiles track
# Track generation: 1056..1329 -> 273-tiles track
# Track generation: 914..1150 -> 236-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 976..1224 -> 248-tiles track
# Track generation: 1233..1545 -> 312-tiles track
# Track generation: 1040..1304 -> 264-tiles track
# Track generation: 1196..1499 -> 303-tiles track
# Track generation: 966..1218 -> 252-tiles track
# Track generation: 1118..1402 -> 284-tiles track
# Track generation: 1104..1384 -> 280-tiles track
# Ep 220	Last score: -18.03	Moving average score: 8.26
# Track generation: 1018..1283 -> 265-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# updating
# Track generation: 1145..1435 -> 290-tiles track
# Track generation: 1023..1283 -> 260-tiles track
# Track generation: 1300..1629 -> 329-tiles track
# Track generation: 1172..1476 -> 304-tiles track
# Track generation: 1115..1397 -> 282-tiles track
# Track generation: 1151..1453 -> 302-tiles track
# Track generation: 1105..1386 -> 281-tiles track
# Track generation: 1114..1396 -> 282-tiles track
# Ep 230	Last score: -17.97	Moving average score: 9.54
# Track generation: 1087..1367 -> 280-tiles track
# Track generation: 1080..1354 -> 274-tiles track
# Track generation: 1252..1569 -> 317-tiles track
# Track generation: 1095..1383 -> 288-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1103..1386 -> 283-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1231..1543 -> 312-tiles track
# Track generation: 1058..1327 -> 269-tiles track
# Track generation: 1214..1522 -> 308-tiles track
# Track generation: 1218..1526 -> 308-tiles track
# Track generation: 1162..1457 -> 295-tiles track
# Ep 240	Last score: -17.97	Moving average score: 10.04
# Track generation: 1070..1341 -> 271-tiles track
# Track generation: 1109..1390 -> 281-tiles track
# Track generation: 1288..1614 -> 326-tiles track
# updating
# Track generation: 1243..1557 -> 314-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# Track generation: 1059..1324 -> 265-tiles track
# Track generation: 1112..1395 -> 283-tiles track
# Track generation: 1030..1292 -> 262-tiles track
# Track generation: 1006..1267 -> 261-tiles track
# Track generation: 1176..1474 -> 298-tiles track
# Ep 250	Last score: -18.03	Moving average score: 9.32
# Track generation: 1095..1373 -> 278-tiles track
# Track generation: 1147..1446 -> 299-tiles track
# Track generation: 1323..1658 -> 335-tiles track
# Track generation: 1066..1342 -> 276-tiles track
# Track generation: 1123..1408 -> 285-tiles track
# Track generation: 1124..1409 -> 285-tiles track
# Track generation: 1300..1635 -> 335-tiles track
# Track generation: 1119..1413 -> 294-tiles track
# Track generation: 1236..1549 -> 313-tiles track
# Track generation: 1212..1519 -> 307-tiles track
# Ep 260	Last score: -17.97	Moving average score: 9.32
# Track generation: 1179..1483 -> 304-tiles track
# Track generation: 1138..1427 -> 289-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1091..1375 -> 284-tiles track
# updating
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1088..1363 -> 275-tiles track
# Track generation: 938..1185 -> 247-tiles track
# Track generation: 1344..1684 -> 340-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Ep 270	Last score: 14.54	Moving average score: 8.12
# Track generation: 1255..1573 -> 318-tiles track
# Track generation: 1147..1438 -> 291-tiles track
# Track generation: 1345..1684 -> 339-tiles track
# Track generation: 1143..1433 -> 290-tiles track
# Track generation: 1128..1414 -> 286-tiles track
# Track generation: 1236..1549 -> 313-tiles track
# Track generation: 1161..1464 -> 303-tiles track
# Track generation: 989..1246 -> 257-tiles track
# Track generation: 1052..1319 -> 267-tiles track
# Track generation: 1088..1364 -> 276-tiles track
# Ep 280	Last score: 14.85	Moving average score: 7.84
# Track generation: 1384..1734 -> 350-tiles track
# Track generation: 878..1102 -> 224-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1154..1446 -> 292-tiles track
# Track generation: 894..1126 -> 232-tiles track
# Track generation: 1237..1550 -> 313-tiles track
# Track generation: 1108..1389 -> 281-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1118..1410 -> 292-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1036..1299 -> 263-tiles track
# Track generation: 1027..1288 -> 261-tiles track
# updating
# Ep 290	Last score: 13.48	Moving average score: 7.29
# Track generation: 1117..1400 -> 283-tiles track
# Track generation: 1211..1518 -> 307-tiles track
# Track generation: 1287..1613 -> 326-tiles track
# Track generation: 1005..1267 -> 262-tiles track
# Track generation: 1113..1404 -> 291-tiles track
# Track generation: 1093..1376 -> 283-tiles track
# Track generation: 1145..1444 -> 299-tiles track
# Track generation: 1220..1533 -> 313-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1077..1358 -> 281-tiles track
# Track generation: 982..1240 -> 258-tiles track
# Track generation: 1174..1471 -> 297-tiles track
# Ep 300	Last score: 16.50	Moving average score: 8.17
# Track generation: 1150..1442 -> 292-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# Track generation: 1118..1405 -> 287-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1130..1417 -> 287-tiles track
# Track generation: 974..1224 -> 250-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1066..1346 -> 280-tiles track
# Track generation: 1247..1563 -> 316-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1099..1383 -> 284-tiles track
# Track generation: 1076..1348 -> 272-tiles track
# Track generation: 1223..1542 -> 319-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Ep 310	Last score: -17.92	Moving average score: 7.22
# Track generation: 1143..1433 -> 290-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1112..1402 -> 290-tiles track
# Track generation: 1176..1474 -> 298-tiles track
# Track generation: 1068..1339 -> 271-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1236..1549 -> 313-tiles track
# updating
# Track generation: 1192..1503 -> 311-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1145..1435 -> 290-tiles track
# Ep 320	Last score: 21.86	Moving average score: 7.01
# Track generation: 1051..1323 -> 272-tiles track
# Track generation: 1012..1277 -> 265-tiles track
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1069..1343 -> 274-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1231..1543 -> 312-tiles track
# Track generation: 1013..1270 -> 257-tiles track
# Track generation: 1100..1380 -> 280-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 956..1207 -> 251-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Ep 330	Last score: 19.90	Moving average score: 7.32
# Track generation: 995..1250 -> 255-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1057..1326 -> 269-tiles track
# Track generation: 1176..1474 -> 298-tiles track
# Track generation: 1103..1389 -> 286-tiles track
# Track generation: 1093..1373 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1040..1313 -> 273-tiles track
# Track generation: 1012..1271 -> 259-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1066..1337 -> 271-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# Track generation: 1039..1303 -> 264-tiles track
# Track generation: 991..1243 -> 252-tiles track
# Track generation: 1019..1278 -> 259-tiles track
# Ep 340	Last score: 20.99	Moving average score: 8.23
# Track generation: 1411..1768 -> 357-tiles track
# Track generation: 1048..1317 -> 269-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1044..1317 -> 273-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1339..1678 -> 339-tiles track
# Track generation: 1047..1313 -> 266-tiles track
# updating
# Track generation: 1238..1552 -> 314-tiles track
# Track generation: 1293..1620 -> 327-tiles track
# Track generation: 1063..1333 -> 270-tiles track
# Track generation: 1206..1512 -> 306-tiles track
# Track generation: 1231..1543 -> 312-tiles track
# Ep 350	Last score: -19.66	Moving average score: 7.76
# Track generation: 1169..1470 -> 301-tiles track
# Track generation: 1204..1509 -> 305-tiles track
# Track generation: 995..1251 -> 256-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1111..1393 -> 282-tiles track
# Track generation: 1291..1618 -> 327-tiles track
# Track generation: 1111..1401 -> 290-tiles track
# Track generation: 1062..1332 -> 270-tiles track
# Track generation: 976..1233 -> 257-tiles track
# Track generation: 1202..1507 -> 305-tiles track
# Track generation: 1111..1400 -> 289-tiles track
# Ep 360	Last score: 22.77	Moving average score: 8.38
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1032..1300 -> 268-tiles track
# Track generation: 1012..1269 -> 257-tiles track
# Track generation: 1142..1432 -> 290-tiles track
# Track generation: 1112..1394 -> 282-tiles track
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1143..1433 -> 290-tiles track
# Track generation: 1235..1550 -> 315-tiles track
# Track generation: 1110..1392 -> 282-tiles track
# Ep 370	Last score: 17.58	Moving average score: 8.71
# Track generation: 1201..1505 -> 304-tiles track
# Track generation: 1212..1519 -> 307-tiles track
# updating
# Track generation: 1169..1465 -> 296-tiles track
# Track generation: 1051..1323 -> 272-tiles track
# Track generation: 1104..1428 -> 324-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1230..1542 -> 312-tiles track
# Track generation: 1124..1409 -> 285-tiles track
# Track generation: 1220..1529 -> 309-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1114..1398 -> 284-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# Ep 380	Last score: -18.09	Moving average score: 8.58
# Track generation: 1061..1339 -> 278-tiles track
# Track generation: 947..1198 -> 251-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1289..1616 -> 327-tiles track
# Track generation: 953..1202 -> 249-tiles track
# Track generation: 1113..1400 -> 287-tiles track
# Track generation: 1219..1528 -> 309-tiles track
# Track generation: 1111..1393 -> 282-tiles track
# Track generation: 1079..1353 -> 274-tiles track
# Track generation: 1146..1437 -> 291-tiles track
# Ep 390	Last score: 14.01	Moving average score: 8.39
# Track generation: 1211..1518 -> 307-tiles track
# Track generation: 1238..1550 -> 312-tiles track
# Track generation: 1267..1588 -> 321-tiles track
# Track generation: 1227..1538 -> 311-tiles track
# Track generation: 1320..1654 -> 334-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1107..1387 -> 280-tiles track
# Track generation: 1319..1653 -> 334-tiles track
# Track generation: 1128..1414 -> 286-tiles track
# updating
# Track generation: 1226..1537 -> 311-tiles track
# Ep 400	Last score: 11.34	Moving average score: 7.07
# Track generation: 907..1145 -> 238-tiles track
# Track generation: 1032..1294 -> 262-tiles track
# Track generation: 1104..1384 -> 280-tiles track
# Track generation: 1276..1599 -> 323-tiles track
# Track generation: 1078..1352 -> 274-tiles track
# Track generation: 1219..1528 -> 309-tiles track
# Track generation: 1000..1254 -> 254-tiles track
# Track generation: 1221..1530 -> 309-tiles track
# Track generation: 1194..1496 -> 302-tiles track
# Track generation: 1265..1585 -> 320-tiles track
# Ep 410	Last score: 14.94	Moving average score: 7.75
# Track generation: 993..1247 -> 254-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1227..1538 -> 311-tiles track
# Track generation: 1019..1278 -> 259-tiles track
# Track generation: 1091..1368 -> 277-tiles track
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1215..1521 -> 306-tiles track
# Track generation: 1085..1366 -> 281-tiles track
# Track generation: 1158..1451 -> 293-tiles track
# Track generation: 1295..1622 -> 327-tiles track
# Track generation: 1171..1468 -> 297-tiles track
# Track generation: 962..1214 -> 252-tiles track
# Ep 420	Last score: 23.13	Moving average score: 8.33
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1215..1523 -> 308-tiles track
# Track generation: 1075..1356 -> 281-tiles track
# Track generation: 953..1201 -> 248-tiles track
# Track generation: 1141..1440 -> 299-tiles track
# Track generation: 1318..1652 -> 334-tiles track
# updating
# Track generation: 1211..1518 -> 307-tiles track
# Track generation: 1116..1399 -> 283-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Ep 430	Last score: 22.78	Moving average score: 8.76
# Track generation: 1088..1364 -> 276-tiles track
# Track generation: 1099..1378 -> 279-tiles track
# Track generation: 1176..1484 -> 308-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1122..1407 -> 285-tiles track
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1171..1468 -> 297-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1006..1266 -> 260-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1031..1300 -> 269-tiles track
# Track generation: 1141..1429 -> 288-tiles track
# Track generation: 1145..1441 -> 296-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# Ep 440	Last score: 32.41	Moving average score: 9.79
# Track generation: 1171..1474 -> 303-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1341..1680 -> 339-tiles track
# Track generation: 1020..1286 -> 266-tiles track
# Track generation: 1164..1460 -> 296-tiles track
# Track generation: 1171..1468 -> 297-tiles track
# Track generation: 1185..1486 -> 301-tiles track
# Track generation: 1158..1461 -> 303-tiles track
# Track generation: 948..1189 -> 241-tiles track
# Ep 450	Last score: 26.87	Moving average score: 9.63
# Track generation: 1142..1432 -> 290-tiles track
# Track generation: 1009..1271 -> 262-tiles track
# Track generation: 1128..1417 -> 289-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1276..1600 -> 324-tiles track
# Track generation: 1022..1291 -> 269-tiles track
# Track generation: 973..1227 -> 254-tiles track
# Track generation: 982..1235 -> 253-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1037..1301 -> 264-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 975..1228 -> 253-tiles track
# updating
# Track generation: 1194..1504 -> 310-tiles track
# Ep 460	Last score: 20.08	Moving average score: 10.54
# Track generation: 1060..1329 -> 269-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# Track generation: 1087..1367 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1175..1473 -> 298-tiles track
# Track generation: 1104..1383 -> 279-tiles track
# Track generation: 1185..1486 -> 301-tiles track
# Track generation: 1078..1352 -> 274-tiles track
# Track generation: 1114..1397 -> 283-tiles track
# Track generation: 933..1175 -> 242-tiles track
# Ep 470	Last score: 13.49	Moving average score: 11.22
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1134..1431 -> 297-tiles track
# Track generation: 1091..1368 -> 277-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1087..1363 -> 276-tiles track
# Track generation: 1040..1306 -> 266-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1054..1322 -> 268-tiles track
# Track generation: 1212..1519 -> 307-tiles track
# Track generation: 1066..1336 -> 270-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1055..1328 -> 273-tiles track
# Ep 480	Last score: 10.79	Moving average score: 11.65
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1091..1368 -> 277-tiles track
# Track generation: 1057..1325 -> 268-tiles track
# Track generation: 993..1250 -> 257-tiles track
# Track generation: 1044..1309 -> 265-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1249..1566 -> 317-tiles track
# Track generation: 1225..1535 -> 310-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1120..1405 -> 285-tiles track
# Ep 490	Last score: 36.75	Moving average score: 13.07
# Track generation: 1081..1363 -> 282-tiles track
# Track generation: 1188..1490 -> 302-tiles track
# Track generation: 960..1204 -> 244-tiles track
# Track generation: 1075..1353 -> 278-tiles track
# updating
# Track generation: 1186..1501 -> 315-tiles track
# Track generation: 1040..1304 -> 264-tiles track
# Track generation: 1195..1498 -> 303-tiles track
# Track generation: 1123..1408 -> 285-tiles track
# Track generation: 1235..1548 -> 313-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Ep 500	Last score: 23.26	Moving average score: 13.49
# Track generation: 1124..1401 -> 277-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1172..1469 -> 297-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1197..1500 -> 303-tiles track
# Track generation: 1020..1333 -> 313-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1128..1414 -> 286-tiles track
# Track generation: 1275..1598 -> 323-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1244..1559 -> 315-tiles track
# Track generation: 1243..1558 -> 315-tiles track
# Track generation: 1401..1761 -> 360-tiles track
# Ep 510	Last score: 8.31	Moving average score: 13.40
# Track generation: 1265..1585 -> 320-tiles track
# Track generation: 1302..1631 -> 329-tiles track
# Track generation: 1101..1380 -> 279-tiles track
# Track generation: 1108..1389 -> 281-tiles track
# Track generation: 1239..1553 -> 314-tiles track
# Track generation: 1337..1675 -> 338-tiles track
# Track generation: 1062..1331 -> 269-tiles track
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1071..1343 -> 272-tiles track
# Track generation: 1049..1315 -> 266-tiles track
# Ep 520	Last score: 29.72	Moving average score: 15.47
# Track generation: 1102..1383 -> 281-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1268..1589 -> 321-tiles track
# Track generation: 1222..1531 -> 309-tiles track
# Track generation: 1174..1471 -> 297-tiles track
# Track generation: 984..1237 -> 253-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1198..1501 -> 303-tiles track
# Track generation: 1033..1303 -> 270-tiles track
# Track generation: 1112..1396 -> 284-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1208..1521 -> 313-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# Track generation: 1132..1427 -> 295-tiles track
# Track generation: 1048..1323 -> 275-tiles track
# updating
# Track generation: 1156..1449 -> 293-tiles track
# Ep 530	Last score: 16.59	Moving average score: 15.81
# Track generation: 1351..1702 -> 351-tiles track
# Track generation: 1004..1264 -> 260-tiles track
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1206..1512 -> 306-tiles track
# Track generation: 1209..1515 -> 306-tiles track
# Track generation: 1121..1405 -> 284-tiles track
# Track generation: 1175..1473 -> 298-tiles track
# Track generation: 1186..1485 -> 299-tiles track
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# Ep 540	Last score: 28.11	Moving average score: 17.12
# Track generation: 1137..1425 -> 288-tiles track
# Track generation: 998..1254 -> 256-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1095..1377 -> 282-tiles track
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1040..1304 -> 264-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1201..1506 -> 305-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1192..1494 -> 302-tiles track
# Track generation: 1220..1529 -> 309-tiles track
# Track generation: 1222..1531 -> 309-tiles track
# Ep 550	Last score: 19.58	Moving average score: 17.62
# Track generation: 1240..1553 -> 313-tiles track
# Track generation: 1014..1278 -> 264-tiles track
# Track generation: 1284..1609 -> 325-tiles track
# Track generation: 1086..1367 -> 281-tiles track
# Track generation: 1333..1670 -> 337-tiles track
# Track generation: 1168..1464 -> 296-tiles track
# Track generation: 1034..1300 -> 266-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1228..1550 -> 322-tiles track
# Track generation: 1276..1599 -> 323-tiles track
# Track generation: 1272..1594 -> 322-tiles track
# Track generation: 1185..1485 -> 300-tiles track
# Ep 560	Last score: 41.10	Moving average score: 17.96
# Track generation: 1070..1352 -> 282-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1082..1364 -> 282-tiles track
# Track generation: 989..1249 -> 260-tiles track
# Track generation: 996..1249 -> 253-tiles track
# updating
# Track generation: 1059..1333 -> 274-tiles track
# Track generation: 1061..1338 -> 277-tiles track
# Track generation: 1019..1281 -> 262-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1172..1469 -> 297-tiles track
# Ep 570	Last score: 8.78	Moving average score: 20.54
# Track generation: 1134..1422 -> 288-tiles track
# Track generation: 1051..1318 -> 267-tiles track
# Track generation: 1070..1342 -> 272-tiles track
# Track generation: 1072..1350 -> 278-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1105..1395 -> 290-tiles track
# Track generation: 1120..1404 -> 284-tiles track
# Track generation: 1284..1609 -> 325-tiles track
# Track generation: 1161..1456 -> 295-tiles track
# Track generation: 1262..1581 -> 319-tiles track
# Ep 580	Last score: 23.69	Moving average score: 24.27
# Track generation: 1123..1408 -> 285-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1045..1310 -> 265-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1270..1599 -> 329-tiles track
# Track generation: 1141..1430 -> 289-tiles track
# Track generation: 1034..1304 -> 270-tiles track
# Track generation: 1093..1367 -> 274-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1176..1477 -> 301-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1236..1549 -> 313-tiles track
# Ep 590	Last score: 21.00	Moving average score: 23.71
# Track generation: 1073..1345 -> 272-tiles track
# Track generation: 1096..1373 -> 277-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1217..1534 -> 317-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1214..1521 -> 307-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1026..1294 -> 268-tiles track
# Track generation: 1279..1603 -> 324-tiles track
# updating
# Ep 600	Last score: 23.89	Moving average score: 24.23
# Track generation: 1173..1477 -> 304-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 965..1218 -> 253-tiles track
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1245..1560 -> 315-tiles track
# Track generation: 983..1233 -> 250-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# Track generation: 1129..1415 -> 286-tiles track
# Track generation: 1416..1774 -> 358-tiles track
# Track generation: 1024..1284 -> 260-tiles track
# Ep 610	Last score: 26.88	Moving average score: 28.14
# Track generation: 1145..1438 -> 293-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1220..1529 -> 309-tiles track
# Track generation: 1062..1332 -> 270-tiles track
# Track generation: 1048..1314 -> 266-tiles track
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1276..1599 -> 323-tiles track
# Track generation: 1082..1357 -> 275-tiles track
# Track generation: 1235..1548 -> 313-tiles track
# Track generation: 1144..1437 -> 293-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1141..1429 -> 288-tiles track
# Track generation: 1186..1487 -> 301-tiles track
# Ep 620	Last score: 40.43	Moving average score: 29.75
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1269..1591 -> 322-tiles track
# Track generation: 1203..1507 -> 304-tiles track
# Track generation: 1175..1473 -> 298-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 963..1208 -> 245-tiles track
# Track generation: 1189..1497 -> 308-tiles track
# Track generation: 1117..1400 -> 283-tiles track
# Track generation: 1061..1337 -> 276-tiles track
# Track generation: 974..1231 -> 257-tiles track
# Ep 630	Last score: 56.09	Moving average score: 30.40
# Track generation: 1211..1525 -> 314-tiles track
# updating
# Track generation: 1183..1488 -> 305-tiles track
# Track generation: 1218..1527 -> 309-tiles track
# Track generation: 1229..1541 -> 312-tiles track
# Track generation: 1206..1511 -> 305-tiles track
# Track generation: 1252..1569 -> 317-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1164..1459 -> 295-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Ep 640	Last score: 35.24	Moving average score: 30.90
# Track generation: 1010..1275 -> 265-tiles track
# Track generation: 1150..1440 -> 290-tiles track
# Track generation: 1087..1363 -> 276-tiles track
# Track generation: 1215..1522 -> 307-tiles track
# Track generation: 1045..1310 -> 265-tiles track
# Track generation: 1093..1371 -> 278-tiles track
# Track generation: 984..1240 -> 256-tiles track
# Track generation: 1147..1445 -> 298-tiles track
# Track generation: 1186..1487 -> 301-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# Ep 650	Last score: 41.33	Moving average score: 34.63
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1261..1580 -> 319-tiles track
# Track generation: 1316..1649 -> 333-tiles track
# Track generation: 1011..1275 -> 264-tiles track
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1154..1447 -> 293-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1006..1264 -> 258-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1181..1481 -> 300-tiles track
# Ep 660	Last score: 46.96	Moving average score: 34.88
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1051..1325 -> 274-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1130..1422 -> 292-tiles track
# updating
# Track generation: 804..1014 -> 210-tiles track
# Track generation: 1308..1639 -> 331-tiles track
# Track generation: 1118..1407 -> 289-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# Track generation: 1099..1378 -> 279-tiles track
# Track generation: 1060..1329 -> 269-tiles track
# Ep 670	Last score: 253.73	Moving average score: 38.72
# Track generation: 1178..1482 -> 304-tiles track
# Track generation: 1173..1470 -> 297-tiles track
# Track generation: 1080..1362 -> 282-tiles track
# Track generation: 988..1239 -> 251-tiles track
# Track generation: 1327..1663 -> 336-tiles track
# Track generation: 1145..1438 -> 293-tiles track
# Track generation: 1108..1398 -> 290-tiles track
# Track generation: 1275..1598 -> 323-tiles track
# Track generation: 1440..1804 -> 364-tiles track
# Track generation: 1112..1394 -> 282-tiles track
# Ep 680	Last score: 42.23	Moving average score: 38.07
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1029..1295 -> 266-tiles track
# Track generation: 1176..1471 -> 295-tiles track
# Track generation: 1159..1459 -> 300-tiles track
# Track generation: 1112..1399 -> 287-tiles track
# Track generation: 1081..1355 -> 274-tiles track
# Track generation: 1143..1433 -> 290-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# Track generation: 979..1232 -> 253-tiles track
# Track generation: 1270..1591 -> 321-tiles track
# Ep 690	Last score: 26.30	Moving average score: 40.79
# Track generation: 1211..1518 -> 307-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1151..1443 -> 292-tiles track
# updating
# Track generation: 1295..1623 -> 328-tiles track
# Track generation: 1348..1689 -> 341-tiles track
# Track generation: 1138..1426 -> 288-tiles track
# Track generation: 946..1188 -> 242-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1176..1474 -> 298-tiles track
# Track generation: 1101..1382 -> 281-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1094..1371 -> 277-tiles track
# Track generation: 1044..1309 -> 265-tiles track
# Ep 700	Last score: 47.48	Moving average score: 47.79
# Track generation: 1031..1301 -> 270-tiles track
# Track generation: 1176..1481 -> 305-tiles track
# Track generation: 1212..1526 -> 314-tiles track
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 977..1231 -> 254-tiles track
# Track generation: 1039..1303 -> 264-tiles track
# Track generation: 1062..1338 -> 276-tiles track
# Track generation: 1088..1364 -> 276-tiles track
# Track generation: 1253..1570 -> 317-tiles track
# Track generation: 1082..1357 -> 275-tiles track
# Ep 710	Last score: 38.09	Moving average score: 54.14
# Track generation: 1021..1288 -> 267-tiles track
# Track generation: 1133..1452 -> 319-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1191..1503 -> 312-tiles track
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1151..1443 -> 292-tiles track
# Track generation: 1005..1264 -> 259-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1049..1315 -> 266-tiles track
# Track generation: 1201..1505 -> 304-tiles track
# updating
# Track generation: 1116..1399 -> 283-tiles track
# Track generation: 1274..1595 -> 321-tiles track
# Ep 720	Last score: 171.88	Moving average score: 65.19
# Track generation: 1328..1664 -> 336-tiles track
# Track generation: 1087..1363 -> 276-tiles track
# Track generation: 1267..1588 -> 321-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1046..1312 -> 266-tiles track
# Track generation: 1090..1375 -> 285-tiles track
# Track generation: 1054..1324 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1088..1364 -> 276-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# Track generation: 1336..1674 -> 338-tiles track
# Ep 730	Last score: 204.75	Moving average score: 72.80
# Track generation: 1275..1598 -> 323-tiles track
# Track generation: 1043..1314 -> 271-tiles track
# Track generation: 1293..1621 -> 328-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1133..1420 -> 287-tiles track
# Track generation: 1144..1434 -> 290-tiles track
# Track generation: 1116..1408 -> 292-tiles track
# Track generation: 1128..1418 -> 290-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1227..1538 -> 311-tiles track
# Track generation: 1021..1283 -> 262-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1195..1498 -> 303-tiles track
# updating
# Track generation: 1119..1368 -> 249-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1133..1429 -> 296-tiles track
# Ep 740	Last score: 56.08	Moving average score: 77.45
# Track generation: 1273..1595 -> 322-tiles track
# Track generation: 1014..1271 -> 257-tiles track
# Track generation: 1174..1476 -> 302-tiles track
# Track generation: 1162..1457 -> 295-tiles track
# Track generation: 1063..1333 -> 270-tiles track
# Track generation: 1289..1623 -> 334-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1284..1609 -> 325-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Ep 750	Last score: 277.23	Moving average score: 85.67
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1082..1362 -> 280-tiles track
# Track generation: 1032..1296 -> 264-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1027..1288 -> 261-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1326..1661 -> 335-tiles track
# Track generation: 1201..1514 -> 313-tiles track
# Track generation: 1168..1464 -> 296-tiles track
# Track generation: 1237..1550 -> 313-tiles track
# ...
# Track generation: 1071..1352 -> 281-tiles track
# Track generation: 1108..1389 -> 281-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1187..1488 -> 301-tiles track
# Track generation: 1165..1460 -> 295-tiles track
# Track generation: 1022..1284 -> 262-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1313..1646 -> 333-tiles track
# Ep 960	Last score: 527.11	Moving average score: 334.80
# Track generation: 1009..1274 -> 265-tiles track
# Track generation: 1149..1445 -> 296-tiles track
# Track generation: 1267..1588 -> 321-tiles track
# Track generation: 969..1220 -> 251-tiles track
# Track generation: 975..1227 -> 252-tiles track
# Track generation: 1131..1425 -> 294-tiles track
# Track generation: 1271..1593 -> 322-tiles track
# Track generation: 1161..1455 -> 294-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1219..1528 -> 309-tiles track
# Ep 970	Last score: 506.49	Moving average score: 334.20
# Track generation: 1237..1552 -> 315-tiles track
# updating
# Track generation: 1076..1351 -> 275-tiles track
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1240..1554 -> 314-tiles track
# Track generation: 1231..1543 -> 312-tiles track
# Track generation: 1054..1329 -> 275-tiles track
# Track generation: 1031..1301 -> 270-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1333..1670 -> 337-tiles track
# Track generation: 1323..1658 -> 335-tiles track
# Ep 980	Last score: 332.34	Moving average score: 351.85
# Track generation: 1087..1362 -> 275-tiles track
# Track generation: 1187..1488 -> 301-tiles track
# Track generation: 1062..1331 -> 269-tiles track
# Track generation: 1081..1355 -> 274-tiles track
# Track generation: 1096..1374 -> 278-tiles track
# Track generation: 1272..1594 -> 322-tiles track
# Track generation: 1211..1518 -> 307-tiles track
# Track generation: 1091..1368 -> 277-tiles track
# updating
# Track generation: 1217..1527 -> 310-tiles track
# Track generation: 1157..1450 -> 293-tiles track
# Ep 990	Last score: 472.60	Moving average score: 359.84
# Track generation: 1106..1387 -> 281-tiles track
# Track generation: 943..1188 -> 245-tiles track
# Track generation: 1170..1467 -> 297-tiles track
# Track generation: 1214..1531 -> 317-tiles track
# Track generation: 1288..1614 -> 326-tiles track
# Track generation: 1124..1409 -> 285-tiles track
# Track generation: 1271..1593 -> 322-tiles track
# Track generation: 933..1174 -> 241-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# Ep 1000	Last score: 561.40	Moving average score: 370.27
# Track generation: 1149..1446 -> 297-tiles track
# Track generation: 1313..1645 -> 332-tiles track
# Track generation: 1050..1317 -> 267-tiles track
# Track generation: 1063..1334 -> 271-tiles track
# Track generation: 1212..1519 -> 307-tiles track
# updating
# Track generation: 1132..1426 -> 294-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1236..1549 -> 313-tiles track
# Track generation: 1194..1496 -> 302-tiles track
# Track generation: 1253..1570 -> 317-tiles track
# Ep 1010	Last score: 493.67	Moving average score: 373.09
# Track generation: 902..1136 -> 234-tiles track
# Track generation: 1130..1417 -> 287-tiles track
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1127..1421 -> 294-tiles track
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1110..1398 -> 288-tiles track
# Track generation: 1069..1347 -> 278-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1203..1517 -> 314-tiles track
# Track generation: 1034..1302 -> 268-tiles track
# Track generation: 1443..1808 -> 365-tiles track
# Ep 1020	Last score: 296.70	Moving average score: 373.13
# Track generation: 1231..1543 -> 312-tiles track
# Track generation: 1182..1482 -> 300-tiles track
# Track generation: 1202..1495 -> 293-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1128..1421 -> 293-tiles track
# Track generation: 1189..1490 -> 301-tiles track
# updating
# Track generation: 1135..1432 -> 297-tiles track
# Track generation: 1142..1432 -> 290-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1128..1414 -> 286-tiles track
# Track generation: 1125..1410 -> 285-tiles track
# Track generation: 1130..1417 -> 287-tiles track
# Ep 1030	Last score: 636.36	Moving average score: 378.49
# Track generation: 1011..1268 -> 257-tiles track
# Track generation: 1061..1335 -> 274-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1320..1654 -> 334-tiles track
# Track generation: 1161..1455 -> 294-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1206..1510 -> 304-tiles track
# Track generation: 1132..1422 -> 290-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1186..1487 -> 301-tiles track
# Track generation: 1187..1498 -> 311-tiles track
# Ep 1040	Last score: 541.94	Moving average score: 385.46
# Track generation: 1114..1407 -> 293-tiles track
# Track generation: 1169..1475 -> 306-tiles track
# updating
# Track generation: 1004..1266 -> 262-tiles track
# Track generation: 1173..1470 -> 297-tiles track
# Track generation: 1036..1299 -> 263-tiles track
# Track generation: 1075..1347 -> 272-tiles track
# Track generation: 1237..1550 -> 313-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1172..1474 -> 302-tiles track
# Track generation: 1142..1432 -> 290-tiles track
# Ep 1050	Last score: 301.98	Moving average score: 385.45
# Track generation: 1144..1434 -> 290-tiles track
# Track generation: 1100..1378 -> 278-tiles track
# Track generation: 1074..1357 -> 283-tiles track
# Track generation: 1160..1455 -> 295-tiles track
# Track generation: 1122..1407 -> 285-tiles track
# Track generation: 1035..1298 -> 263-tiles track
# Track generation: 1212..1519 -> 307-tiles track
# Track generation: 1212..1519 -> 307-tiles track
# Track generation: 1043..1308 -> 265-tiles track
# Track generation: 1059..1328 -> 269-tiles track
# Ep 1060	Last score: 764.93	Moving average score: 397.46
# Track generation: 1113..1402 -> 289-tiles track
# updating
# Track generation: 1070..1345 -> 275-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1305..1635 -> 330-tiles track
# Track generation: 949..1199 -> 250-tiles track
# Track generation: 1164..1459 -> 295-tiles track
# Track generation: 1108..1397 -> 289-tiles track
# Track generation: 1224..1534 -> 310-tiles track
# Track generation: 1006..1268 -> 262-tiles track
# Track generation: 983..1235 -> 252-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1019..1287 -> 268-tiles track
# Track generation: 1023..1283 -> 260-tiles track
# Track generation: 1238..1552 -> 314-tiles track
# Ep 1070	Last score: 699.68	Moving average score: 402.06
# Track generation: 1051..1325 -> 274-tiles track
# Track generation: 1178..1477 -> 299-tiles track
# Track generation: 1116..1399 -> 283-tiles track
# Track generation: 1157..1451 -> 294-tiles track
# Track generation: 1091..1368 -> 277-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1272..1594 -> 322-tiles track
# Track generation: 1177..1475 -> 298-tiles track
# updating
# Track generation: 1290..1622 -> 332-tiles track
# Track generation: 1036..1299 -> 263-tiles track
# Ep 1080	Last score: 362.98	Moving average score: 410.33
# Track generation: 1099..1378 -> 279-tiles track
# Track generation: 1186..1489 -> 303-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1211..1517 -> 306-tiles track
# Track generation: 1215..1524 -> 309-tiles track
# Track generation: 1235..1548 -> 313-tiles track
# Track generation: 1335..1673 -> 338-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1086..1361 -> 275-tiles track
# Track generation: 1067..1338 -> 271-tiles track
# Track generation: 1225..1535 -> 310-tiles track
# Track generation: 1192..1494 -> 302-tiles track
# Ep 1090	Last score: 727.57	Moving average score: 430.69
# Track generation: 992..1244 -> 252-tiles track
# Track generation: 1217..1525 -> 308-tiles track
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\55366\Documents\GitHub\Car_racing\cr_ppo.ipynb Cell 8' in <cell line: 1>()
#      <a href='vscode-notebook-cell:/c%3A/Users/55366/Documents/GitHub/Car_racing/cr_ppo.ipynb#ch0000006?line=11'>12</a> for t in range(1000):
#      <a href='vscode-notebook-cell:/c%3A/Users/55366/Documents/GitHub/Car_racing/cr_ppo.ipynb#ch0000006?line=12'>13</a>     action, a_logp = agent.select_action(state)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/55366/Documents/GitHub/Car_racing/cr_ppo.ipynb#ch0000006?line=13'>14</a>     state_, reward, done, die = env.step(action * np.array([2., 1., 1.]) + np.array([-1., 0., 0.]))
#      <a href='vscode-notebook-cell:/c%3A/Users/55366/Documents/GitHub/Car_racing/cr_ppo.ipynb#ch0000006?line=14'>15</a>     if render:
#      <a href='vscode-notebook-cell:/c%3A/Users/55366/Documents/GitHub/Car_racing/cr_ppo.ipynb#ch0000006?line=15'>16</a>         env.render()
#
# c:\Users\55366\Documents\GitHub\Car_racing\cr_ppo.ipynb Cell 2' in Env.step(self, action)
#      <a href='vscode-notebook-cell:/c%3A/Users/55366/Documents/GitHub/Car_racing/cr_ppo.ipynb#ch0000001?line=17'>18</a> total_reward = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/55366/Documents/GitHub/Car_racing/cr_ppo.ipynb#ch0000001?line=18'>19</a> for i in range(8):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/55366/Documents/GitHub/Car_racing/cr_ppo.ipynb#ch0000001?line=19'>20</a>     img_rgb, reward, die, _ = self.env.step(action)
#      <a href='vscode-notebook-cell:/c%3A/Users/55366/Documents/GitHub/Car_racing/cr_ppo.ipynb#ch0000001?line=20'>21</a>     # don't penalize "die state"
#      <a href='vscode-notebook-cell:/c%3A/Users/55366/Documents/GitHub/Car_racing/cr_ppo.ipynb#ch0000001?line=21'>22</a>     if die:
#
# File c:\Users\55366\anaconda3\envs\ml\lib\site-packages\gym\wrappers\time_limit.py:17, in TimeLimit.step(self, action)
#      <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/wrappers/time_limit.py?line=15'>16</a> def step(self, action):
# ---> <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/wrappers/time_limit.py?line=16'>17</a>     observation, reward, done, info = self.env.step(action)
#      <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/wrappers/time_limit.py?line=17'>18</a>     self._elapsed_steps += 1
#      <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/wrappers/time_limit.py?line=18'>19</a>     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\55366\anaconda3\envs\ml\lib\site-packages\gym\wrappers\order_enforcing.py:13, in OrderEnforcing.step(self, action)
#      <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/wrappers/order_enforcing.py?line=10'>11</a> def step(self, action):
#      <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/wrappers/order_enforcing.py?line=11'>12</a>     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/wrappers/order_enforcing.py?line=12'>13</a>     observation, reward, done, info = self.env.step(action)
#      <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/wrappers/order_enforcing.py?line=13'>14</a>     return observation, reward, done, info
#
# File c:\Users\55366\anaconda3\envs\ml\lib\site-packages\gym\envs\box2d\car_racing.py:419, in CarRacing.step(self, action)
#     <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/envs/box2d/car_racing.py?line=415'>416</a> self.world.Step(1.0 / FPS, 6 * 30, 2 * 30)
#     <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/envs/box2d/car_racing.py?line=416'>417</a> self.t += 1.0 / FPS
# --> <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/envs/box2d/car_racing.py?line=418'>419</a> self.state = self.render("state_pixels")
#     <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/envs/box2d/car_racing.py?line=420'>421</a> step_reward = 0
#     <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/envs/box2d/car_racing.py?line=421'>422</a> done = False
#
# File c:\Users\55366\anaconda3\envs\ml\lib\site-packages\gym\envs\box2d\car_racing.py:468, in CarRacing.render(self, mode)
#     <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/envs/box2d/car_racing.py?line=464'>465</a> # showing stats
#     <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/envs/box2d/car_racing.py?line=465'>466</a> self.render_indicators(WINDOW_W, WINDOW_H)
# --> <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/envs/box2d/car_racing.py?line=467'>468</a> font = pygame.font.Font(pygame.font.get_default_font(), 42)
#     <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/envs/box2d/car_racing.py?line=468'>469</a> text = font.render("%04i" % self.reward, True, (255, 255, 255), (0, 0, 0))
#     <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/gym/envs/box2d/car_racing.py?line=469'>470</a> text_rect = text.get_rect()
#
# File c:\Users\55366\anaconda3\envs\ml\lib\site-packages\pygame\pkgdata.py:68, in getResource(identifier, pkgname)
#      <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/pygame/pkgdata.py?line=65'>66</a> try:
#      <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/pygame/pkgdata.py?line=66'>67</a>     if resource_exists(pkgname, identifier):
# ---> <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/pygame/pkgdata.py?line=67'>68</a>         return resource_stream(pkgname, identifier)
#      <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/pygame/pkgdata.py?line=68'>69</a> except NotImplementedError:
#      <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/pygame/pkgdata.py?line=69'>70</a>     pass
#
# File c:\Users\55366\anaconda3\envs\ml\lib\site-packages\pkg_resources\__init__.py:1136, in ResourceManager.resource_stream(self, package_or_requirement, resource_name)
#    <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/pkg_resources/__init__.py?line=1133'>1134</a> def resource_stream(self, package_or_requirement, resource_name):
#    <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/pkg_resources/__init__.py?line=1134'>1135</a>     """Return a readable file-like object for specified resource"""
# -> <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/pkg_resources/__init__.py?line=1135'>1136</a>     return get_provider(package_or_requirement).get_resource_stream(
#    <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/pkg_resources/__init__.py?line=1136'>1137</a>         self, resource_name
#    <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/pkg_resources/__init__.py?line=1137'>1138</a>     )
#
# File c:\Users\55366\anaconda3\envs\ml\lib\site-packages\pkg_resources\__init__.py:1608, in DefaultProvider.get_resource_stream(self, manager, resource_name)
#    <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/pkg_resources/__init__.py?line=1606'>1607</a> def get_resource_stream(self, manager, resource_name):
# -> <a href='file:///c%3A/Users/55366/anaconda3/envs/ml/lib/site-packages/pkg_resources/__init__.py?line=1607'>1608</a>     return open(self._fn(self.module_path, resource_name), 'rb')
#
# KeyboardInterrupt:
